# %%
# !pip install rouge
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

! cp 'gdrive/My Drive/Ab_Summarization/Our_Own_Code/Seq2Seq Combos/Seq2Seq.py' .

# %%
import os
import time
import pickle
import numpy as np
import pandas as pd
from rouge import Rouge
import tensorflow as tf
from tensorflow.python.layers.core import Dense
from tensorflow.python.ops.rnn_cell_impl import _zero_state_tensors
print('TensorFlow Version: {}'.format(tf.__version__))

from Seq2Seq import Seq2Seq_Model
# Out:
# TensorFlow Version: 1.13.1

# %% [markdown]
# **The different types of experiments**
#
# <ol>
#   <li> Type 1 - emb-pos, bahdanau, greedy, 2 enc-dec, 128 units </li>
#   <li> Type 2 - emb-pos, luong, greedy, 2 enc-dec, 128 units </li>
#   <li> Type 3 - emb-pos, bahdanau, beam(10), 2 enc-dec, 128 units </li>
#   <li> Type 4 - emb-pos, luong, beam(10), 2 enc-dec, 128 units </li>
#   <li> Type 5 - emb, bahdanau, greedy, 2 enc-dec, 128 units </li>
#   <li> Type 6 - emb, luong, greedy, 2 enc-dec, 128 units </li>
#   <li> Type 7 - emb, bahdanau, beam(10), 2 enc-dec, 128 units </li>
#   <li> Type 8 - emb, luong, beam(10), 2 enc-dec, 128 units </li>
#   <li> Type 9 - emb, None, greedy, 2 enc-dec, 128 units </li>
#   <li> Type 10 - emb, None, beam(10), 2 enc-dec, 128 units </li>
#   <li> Type 11 - emb-pos, None, greedy, 2 enc-dec, 128 units </li>
#   <li> Type 12 - emb-pos, None, beam(10), 2 enc-dec, 128 units </li>
#  </ol>

# %%
path = 'gdrive/My Drive/Ab_Summarization/Our_Own_Code/sumdata/train/'
ckpt_path = "gdrive/My Drive/Ab_Summarization/Our_Own_Code/Seq2Seq Combos/Model_Checkpoints_Final/"
type_val = 'type3'

if 1 in [c in type_val for c in ['1','2','3','4','11','12']]:
  emb_name = 'word_embedding_matrix1'
else:
  emb_name = 'word_embedding_matrix'
  
if 1 in [c in type_val for c in ['1','3','5','7']]:
  attn = 'Bahdanau'
else:
  attn = 'Luong'
  
if 1 in [c in type_val for c in ['1','2','5','6','9','11']]:
  dec_mech = 'greedy'
else:
  dec_mech = 'beam'
  
if 1 in [c in type_val for c in ['9','10','11','12']]:
  attn = None

# %%
sorted_summaries = pickle.load(open(path+'summaries.pkl', 'rb'))
sorted_texts = pickle.load(open(path+'texts.pkl', 'rb'))
word_embedding_matrix = pickle.load(open(path+emb_name, 'rb'))
vocab_to_int = pickle.load(open(path+'vocab_to_int', 'rb'))
int_to_vocab = pickle.load(open(path+'int_to_vocab', 'rb'))

# %%
params = {
    'attention_mechanism':attn, #Luong, Bahdanau, None
    'batch_size':128,
    'bidirectional':True, #False, True
    'cell_type':'LSTM',
    'embeddings':word_embedding_matrix,
    'vocab_size':word_embedding_matrix.shape[0],
    'inference_mechanism':dec_mech, #beam, greedy
    'num_decoder_layers':2,
    'num_encoder_layers':2,
    'num_units':128,
    'end_token':'<EOS>',
    'beam_size':10,
    'word2int':vocab_to_int
}

# %%
# use function call help to see the different options possible for each param
ob = Seq2Seq_Model(params)

# %%
train_graph = ob.build_graph(infer=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Cannot reshape a tensor with 327680 elements to shape [1280,10,256] (3276800 elements) for 'Decoder_Network/Reshape' (op: 'Reshape') with input shapes: [1280,256], [3] and with input tensors computed as partial shapes: input[1] = [1280,10,256].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-16f7bd63a646> in <module>()
# ----> 1 train_graph = ob.build_graph(infer=True)
#
# /content/Seq2Seq.py in build_graph(self, infer)
#     279                             self.encoder_final_state = tf.contrib.seq2seq.tile_batch(self.encoder_final_state,self.beam_size)
#     280                         else:
# --> 281                             memory = self.encoder_outputs
#     282                             memory_lengths = self.encoder_lengths
#     283                         self._decoder_with_attention_(memory,memory_lengths)
#
# /content/Seq2Seq.py in _inference_decoder_(self)
#     216                                                                  embedding=self.embeddings,
#     217                                                                  start_tokens=start_tokens,
# --> 218                                                                  end_token=self.word2int[self.end_token],
#     219                                                                  initial_state=self.decoder_initial_state,
#     220                                                                  beam_width=self.beam_size,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/seq2seq/python/ops/beam_search_decoder.py in __init__(self, cell, embedding, start_tokens, end_token, initial_state, beam_width, output_layer, length_penalty_weight, coverage_penalty_weight, reorder_tensor_arrays)
#     339     self._coverage_penalty_weight = coverage_penalty_weight
#     340     self._initial_cell_state = nest.map_structure(
# --> 341         self._maybe_split_batch_beams, initial_state, self._cell.state_size)
#     342     self._start_tokens = array_ops.tile(
#     343         array_ops.expand_dims(self._start_tokens, 1), [1, self._beam_width])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **check_types_dict)
#     379
#     380   return pack_sequence_as(
# --> 381       structure[0], [func(*x) for x in entries])
#     382
#     383
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     379
#     380   return pack_sequence_as(
# --> 381       structure[0], [func(*x) for x in entries])
#     382
#     383
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/seq2seq/python/ops/beam_search_decoder.py in _maybe_split_batch_beams(self, t, s)
#     565     _check_maybe(t)
#     566     if t.shape.ndims >= 1:
# --> 567       return self._split_batch_beams(t, s)
#     568     else:
#     569       return t
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/seq2seq/python/ops/beam_search_decoder.py in _split_batch_beams(self, t, s)
#     529         t,
#     530         array_ops.concat(([self._batch_size, self._beam_width], t_shape[1:]),
# --> 531                          0))
#     532     static_batch_size = tensor_util.constant_value(self._batch_size)
#     533     expected_reshaped_shape = tensor_shape.TensorShape(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    7177   try:
#    7178     _, _, _op = _op_def_lib._apply_op_helper(
# -> 7179         "Reshape", tensor=tensor, shape=shape, name=name)
#    7180   except (TypeError, ValueError):
#    7181     result = _dispatch.dispatch(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Cannot reshape a tensor with 327680 elements to shape [1280,10,256] (3276800 elements) for 'Decoder_Network/Reshape' (op: 'Reshape') with input shapes: [1280,256], [3] and with input tensors computed as partial shapes: input[1] = [1280,10,256].

# %%
len(sorted_texts), len(sorted_summaries)

# %%
# choose number of samples
sorted_sum = sorted_summaries[:1000000]
sorted_tex = sorted_texts[:1000000]
del sorted_summaries, sorted_texts

# %%
split = int(0.7*len(sorted_sum))
train_summaries, test_summaries = sorted_sum[:split], sorted_sum[split:]
train_texts, test_texts = sorted_tex[:split], sorted_tex[split:]

# %%
def pad_sentence_batch(sentence_batch):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [vocab_to_int['<PAD>']] * (max_sentence - len(sentence)) for sentence in sentence_batch]

# %%
def get_batches(summaries, texts, batch_size):
    """Batch summaries, texts, and the lengths of their sentences together"""
    for batch_i in range(0, len(texts)//batch_size):
        start_i = batch_i * batch_size
        summaries_batch = summaries[start_i:start_i + batch_size]
        texts_batch = texts[start_i:start_i + batch_size]
        pad_summaries_batch = np.array(pad_sentence_batch(summaries_batch))
        pad_texts_batch = np.array(pad_sentence_batch(texts_batch))
        
        # Need the lengths for the _lengths parameters
        pad_summaries_lengths = []
        for summary in summaries_batch:
            pad_summaries_lengths.append(len(summary))
        
        pad_texts_lengths = []
        for text in texts_batch:
            pad_texts_lengths.append(len(text))
        
        yield pad_summaries_batch, pad_texts_batch, pad_summaries_lengths, pad_texts_lengths

# %% [markdown]
# ## Testing Scores Overall

# %%
val = 1000
test_limit = 0.20
train_limit = 0.40

# %%
learning_rate = 0.005
checkpoint = "final_best_model_multigraph.ckpt"
with tf.Session(graph=train_graph) as sess:
  saver = tf.train.Saver()
  saver.restore(sess,os.path.join(ckpt_path,type_val,checkpoint))
  test_logits = []
  for batch_i, (summaries_batch, texts_batch, summaries_lengths, texts_lengths) in enumerate(
          get_batches(test_summaries, test_texts, params['batch_size'])):
    ilog = sess.run( ob.inference_logits,
          {ob.encoder_inputs: texts_batch,
           ob.decoder_targets: summaries_batch,
           ob.learning_rate: learning_rate,
           ob.decoder_lengths: summaries_lengths,
           ob.encoder_lengths: texts_lengths})
    print("Batch No. %d of %d"%(batch_i+1,int(len(test_summaries)/params['batch_size'])))
    test_logits.extend(ilog.tolist())
  rouge = Rouge()
  all_pred, all_summ = [], []
  for i in range(len(test_logits)):
    pred = " ".join([int_to_vocab[test_logits[i][k]] if test_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(test_logits[i]))])
    true = " ".join([int_to_vocab[test_summaries[i][k]] if test_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(test_summaries[i]))])
    all_pred.append(pred)
    all_summ.append(true)
  
  scores = rouge.get_scores(all_pred, all_summ, avg = True)
  slist = []
  slist.append(np.round(scores['rouge-1']['p'],decimals=4))
  slist.append(np.round(scores['rouge-1']['r'],decimals=4))
  slist.append(np.round(scores['rouge-1']['f'],decimals=4))
  slist.append(np.round(scores['rouge-2']['p'],decimals=4))
  slist.append(np.round(scores['rouge-2']['r'],decimals=4))
  slist.append(np.round(scores['rouge-2']['f'],decimals=4))
  slist.append(np.round(scores['rouge-l']['p'],decimals=4))
  slist.append(np.round(scores['rouge-l']['r'],decimals=4))
  slist.append(np.round(scores['rouge-l']['f'],decimals=4))
  
  print(scores)
  print(slist)

# %% [markdown]
# ##Test Result Cases

# %%
checkpoint = "final_best_model_multigraph.ckpt" 
with tf.Session(graph=train_graph) as sess:
  saver = tf.train.Saver()
  saver.restore(sess,os.path.join(ckpt_path,type_val,checkpoint))
  test_logits = []
  for batch_i, (summaries_batch, texts_batch, summaries_lengths, texts_lengths) in enumerate(
          get_batches(test_summaries[:val], test_texts[:val], params['batch_size'])):
    ilog = sess.run( ob.inference_logits,
          {ob.encoder_inputs: texts_batch,
           ob.decoder_targets: summaries_batch,
           ob.learning_rate: learning_rate,
           ob.decoder_lengths: summaries_lengths,
           ob.encoder_lengths: texts_lengths})
    print("Batch No. %d of %d"%(batch_i+1,int(len(test_summaries)/params['batch_size'])))
    test_logits.extend(ilog.tolist())
  rouge = Rouge()
  all_pred, all_summ, all_texts = [], [], []
  for i in range(len(test_logits)):
    pred = " ".join([int_to_vocab[test_logits[i][k]] if test_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(test_logits[i]))])
    true = " ".join([int_to_vocab[test_summaries[:val][i][k]] if test_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(test_summaries[:val][i]))])
    text = " ".join([int_to_vocab[test_texts[:val][i][k]] for k in range(len(test_texts[:val][i]))])
    r_values = rouge.get_scores(pred, true)
    if(r_values[0]['rouge-1']['f'] > test_limit):
      print("Text : ", text, "\n", "Actual Summary : ", true, "\n System Summary : ", pred, "\n", r_values, "\n")
# Out:
# INFO:tensorflow:Restoring parameters from gdrive/My Drive/Ab_Summarization/Our_Own_Code/Seq2Seq Combos/Model_Checkpoints_Multigraph/type1/final_best_model_multigraph.ckpt
# Batch No. 1 of 2
# Batch No. 2 of 2
# Text :  a taiwanese man was indicted on friday for allegedly kicking former president chen shui bian in the rear an official at the taipei district prosecutor s office said <EOS>
#  Actual Summary :  man indicted for kicking taiwan s ex president in rear
#  System Summary :  us soldier in iraq for iraq s iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.3749999953125, 'p': 0.5, 'r': 0.3}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.22368421052631188, 'p': 0.3333333333333333, 'r': 0.2}}]
#
# Text :  malaysian share prices ended percent higher friday amid rising plantation and financial stocks but political tensions capped sentiment dealers said <EOS>
#  Actual Summary :  malaysian shares close up percent
#  System Summary :  malaysian shares close lower on oil oil prices rise on oil prices
#  [{'rouge-1': {'f': 0.4615384568047337, 'p': 0.375, 'r': 0.6}, 'rouge-2': {'f': 0.3076923034319527, 'p': 0.2222222222222222, 'r': 0.5}, 'rouge-l': {'f': 0.4191522762944536, 'p': 0.375, 'r': 0.6}}]
#
# Text :  hong kong share prices closed down percent on friday as weakness in chinese banks offset earlier gains in property developers and energy firms dealers said <EOS>
#  Actual Summary :  hong kong shares close down percent
#  System Summary :  hong kong shares close lower lower on oil oil prices rise on
#  [{'rouge-1': {'f': 0.5333333285333334, 'p': 0.4444444444444444, 'r': 0.6666666666666666}, 'rouge-2': {'f': 0.374999995703125, 'p': 0.2727272727272727, 'r': 0.6}, 'rouge-l': {'f': 0.4952380952374046, 'p': 0.4444444444444444, 'r': 0.6666666666666666}}]
#
# Text :  australian stocks were likely to underperform global stocks in the coming week after a volatile week of trading dealers said friday <EOS>
#  Actual Summary :  australian stocks likely to underperform in coming week
#  System Summary :  australian stocks close lower on oil price prices rise on oil price
#  [{'rouge-1': {'f': 0.23529411266435996, 'p': 0.2222222222222222, 'r': 0.25}, 'rouge-2': {'f': 0.12499999507812519, 'p': 0.1111111111111111, 'r': 0.14285714285714285}, 'rouge-l': {'f': 0.23368251410092805, 'p': 0.2222222222222222, 'r': 0.25}}]
#
# Text :  french and british firefighters on friday slowly mastered a degree inferno in the channel tunnel but tens of thousands of travellers faced extended disruption <EOS>
#  Actual Summary :  channel tunnel inferno leaves tens of thousands facing travel chaos
#  System Summary :  thousands of us in iraq s iraq s iraq s iraq s
#  [{'rouge-1': {'f': 0.24999999531250006, 'p': 0.3333333333333333, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11184210526315402, 'p': 0.16666666666666666, 'r': 0.1}}]
#
# Text :  oil prices rose on friday as hurricane ike forced the closure of energy production facilities in the gulf of mexico traders said <EOS>
#  Actual Summary :  oil prices rise as hurricane ike halts us energy production
#  System Summary :  oil prices close lower on oil oil prices prices lower on oil
#  [{'rouge-1': {'f': 0.2666666622222223, 'p': 0.4, 'r': 0.2}, 'rouge-2': {'f': 0.11764705384083066, 'p': 0.125, 'r': 0.1111111111111111}, 'rouge-l': {'f': 0.22222222222229632, 'p': 0.4, 'r': 0.2}}]
#
# Text :  taiwan share prices are expected to stage a rebound next week as institutional investors show interest in badly hit blue chips after recent heavy losses dealers said <EOS>
#  Actual Summary :  taiwan shares may rebound with blue chips in focus
#  System Summary :  taiwan shares close lower on oil oil prices rise on oil prices
#  [{'rouge-1': {'f': 0.23529411266435996, 'p': 0.25, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.11764705384083066, 'p': 0.1111111111111111, 'r': 0.125}, 'rouge-l': {'f': 0.23368251410115778, 'p': 0.25, 'r': 0.2222222222222222}}]
#
# Text :  pope benedict xvi was on his way to france friday for his first visit to the `` eldest daughter of the roman catholic church since he succeeded john paul ii <EOS>
#  Actual Summary :  pope begins visit to france
#  System Summary :  myanmar s new to visit for myanmar s <unk> s <unk> s
#  [{'rouge-1': {'f': 0.33333332847222225, 'p': 0.2857142857142857, 'r': 0.4}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.15811965811896683, 'p': 0.14285714285714285, 'r': 0.2}}]
#
# Text :  hong kong share prices closed down percent on friday as weakness in china banks has offset earlier gains in property developers and energy firms dealers said <EOS>
#  Actual Summary :  hong kong shares close down percent
#  System Summary :  hong kong shares close lower on oil oil prices rise on oil
#  [{'rouge-1': {'f': 0.5333333285333334, 'p': 0.4444444444444444, 'r': 0.6666666666666666}, 'rouge-2': {'f': 0.3999999955555556, 'p': 0.3, 'r': 0.6}, 'rouge-l': {'f': 0.4952380952374046, 'p': 0.4444444444444444, 'r': 0.6666666666666666}}]
#
# Text :  hong kong gold prices closed higher on friday at us dollars an ounce up from thursday s close of dollars <EOS>
#  Actual Summary :  hong kong gold closes higher
#  System Summary :  hong kong gold open lower lower on oil oil prices rise on
#  [{'rouge-1': {'f': 0.4285714239795918, 'p': 0.3333333333333333, 'r': 0.6}, 'rouge-2': {'f': 0.26666666275555556, 'p': 0.18181818181818182, 'r': 0.5}, 'rouge-l': {'f': 0.3723653395778134, 'p': 0.3333333333333333, 'r': 0.6}}]
#
# Text :  south korean shares closed percent higher friday on revived hopes for a sale of lehman brothers and a continued fall in oil prices analysts said <EOS>
#  Actual Summary :  skorean shares close percent higher
#  System Summary :  south korean shares close lower on oil oil prices rise on oil
#  [{'rouge-1': {'f': 0.285714281122449, 'p': 0.2222222222222222, 'r': 0.4}, 'rouge-2': {'f': 0.14285713877551035, 'p': 0.1, 'r': 0.25}, 'rouge-l': {'f': 0.2482435597183287, 'p': 0.2222222222222222, 'r': 0.4}}]
#
# Text :  china reported an easing in industrial output friday providing further evidence its economy is slowing amid a global slump and reinforcing expectations beijing will move to spur growth <EOS>
#  Actual Summary :  slowing industrial growth may push china to further ease tightening
#  System Summary :  china to meet up dollars in iraq s iraq s iraq s
#  [{'rouge-1': {'f': 0.22222221728395072, 'p': 0.25, 'r': 0.2}, 'rouge-2': {'f': 0.11764705384083066, 'p': 0.125, 'r': 0.1111111111111111}, 'rouge-l': {'f': 0.21693121693096162, 'p': 0.25, 'r': 0.2}}]
#
# Text :  us ties with `` war on terror ally pakistan are strained after us commandos unilaterally launched ground assaults on militants on pakistani soil drawing fire from the military chief in islamabad <EOS>
#  Actual Summary :  strain in ties as us launches ground raids inside pakistan
#  System Summary :  us court to be in iraq s iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.23529411280276827, 'p': 0.2857142857142857, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11094564408029664, 'p': 0.14285714285714285, 'r': 0.1}}]
#
# Text :  experts on friday conducted forensic tests on a tiny body found in a tel aviv river thought to be that of a french girl allegedly murdered by her grandfather in a case that has transfixed israel <EOS>
#  Actual Summary :  autopsy in israel on body thought to be murdered french girl
#  System Summary :  iran s us to be in iraq s iraq s iraq s
#  [{'rouge-1': {'f': 0.3333333285802469, 'p': 0.42857142857142855, 'r': 0.2727272727272727}, 'rouge-2': {'f': 0.11111110617283973, 'p': 0.125, 'r': 0.1}, 'rouge-l': {'f': 0.2031063321385475, 'p': 0.2857142857142857, 'r': 0.18181818181818182}}]
#
# Text :  pope benedict xvi left rome on friday for a four day trip to france <EOS>
#  Actual Summary :  pope leaves for four day visit to france
#  System Summary :  taiwan s new to meet for new dollars in iraq s iraq
#  [{'rouge-1': {'f': 0.23529411266435996, 'p': 0.2222222222222222, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11684125705016256, 'p': 0.1111111111111111, 'r': 0.125}}]
#
# Text :  new zealand share prices rose percent friday with sentiment tracking the positive turnaround on wall street dealers said <EOS>
#  Actual Summary :  new zealand shares rise percent
#  System Summary :  new zealand shares close percent lower on oil oil prices rise on
#  [{'rouge-1': {'f': 0.6666666622222223, 'p': 0.5, 'r': 1.0}, 'rouge-2': {'f': 0.26666666275555556, 'p': 0.18181818181818182, 'r': 0.5}, 'rouge-l': {'f': 0.44444444444385184, 'p': 0.4, 'r': 0.8}}]
#
# Text :  world oil prices climbed in asian trade friday as hurricane ike hammered the southern us coast forcing oil and gas production facilities in the area to shut down dealers said <EOS>
#  Actual Summary :  oil prices up as hurricane ike barrels down on texas coast
#  System Summary :  oil shares close percent lower on oil price prices prices lower on
#  [{'rouge-1': {'f': 0.3157894688088643, 'p': 0.375, 'r': 0.2727272727272727}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.3011394465543743, 'p': 0.375, 'r': 0.2727272727272727}}]
#
# Text :  new zealand share prices rose percent friday with sentiment tracking the postive turnaround on wall street dealers said <EOS>
#  Actual Summary :  new zealand shares rise percent
#  System Summary :  new zealand shares close percent lower on oil oil prices rise on
#  [{'rouge-1': {'f': 0.6666666622222223, 'p': 0.5, 'r': 1.0}, 'rouge-2': {'f': 0.26666666275555556, 'p': 0.18181818181818182, 'r': 0.5}, 'rouge-l': {'f': 0.44444444444385184, 'p': 0.4, 'r': 0.8}}]
#
# Text :  south korean shares closed percent higher friday as sentiment was lifted by wall street gains following speculation that lehman brothers is in talks on a possible sale analysts said <EOS>
#  Actual Summary :  skorean shares close percent higher
#  System Summary :  south korean shares close lower on oil oil prices prices lower on
#  [{'rouge-1': {'f': 0.3076923029585799, 'p': 0.25, 'r': 0.4}, 'rouge-2': {'f': 0.14285713877551035, 'p': 0.1, 'r': 0.25}, 'rouge-l': {'f': 0.2794348508627425, 'p': 0.25, 'r': 0.4}}]
#
# Text :  the dollar had mixed fortunes against other major currencies in asian trade friday as markets waited for a potential rescue plan for troubled wall street titan lehman brothers dealers said <EOS>
#  Actual Summary :  dollar gains in asia on us bank hopes
#  System Summary :  dollar stocks close lower on oil oil prices rise on oil oil
#  [{'rouge-1': {'f': 0.24999999500000009, 'p': 0.25, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2499999999995, 'p': 0.25, 'r': 0.25}}]
#
# Text :  taiwan share prices closed percent higher friday as bargain hunting helped the market recoup early losses amid economic concerns dealers said <EOS>
#  Actual Summary :  taipei shares close up percent
#  System Summary :  taipei shares close down percent on oil oil concerns concerns concerns concerns
#  [{'rouge-1': {'f': 0.6153846106508877, 'p': 0.5, 'r': 0.8}, 'rouge-2': {'f': 0.3076923034319527, 'p': 0.2222222222222222, 'r': 0.5}, 'rouge-l': {'f': 0.5588697017261648, 'p': 0.5, 'r': 0.8}}]
#
# Text :  new zealand s prime minister helen clark called general elections for november friday with her labor party behind in opinion polls amid a slowing economy and her foreign minister facing the axe <EOS>
#  Actual Summary :  new zealand pm sets november date for general election
#  System Summary :  new zealand minister to visit for myanmar of iraq s us oil
#  [{'rouge-1': {'f': 0.2857142808163266, 'p': 0.25, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.1052631530193908, 'p': 0.09090909090909091, 'r': 0.125}, 'rouge-l': {'f': 0.2747252747245908, 'p': 0.25, 'r': 0.3333333333333333}}]
#
# Text :  taiwan share prices closed percent higher friday as bargain hunting helped the market recoup early losses amid economic concerns dealers said <EOS>
#  Actual Summary :  taipei shares close up percent
#  System Summary :  taipei shares close down percent on oil oil concerns concerns concerns concerns
#  [{'rouge-1': {'f': 0.6153846106508877, 'p': 0.5, 'r': 0.8}, 'rouge-2': {'f': 0.3076923034319527, 'p': 0.2222222222222222, 'r': 0.5}, 'rouge-l': {'f': 0.5588697017261648, 'p': 0.5, 'r': 0.8}}]
#
# Text :  hong kong share prices ended the morning up percent on friday supported by gains in property developers and energy firms dealers said <EOS>
#  Actual Summary :  hong kong shares up pct in morning
#  System Summary :  hong kong shares close lower on oil oil prices rise on oil
#  [{'rouge-1': {'f': 0.37499999507812504, 'p': 0.3333333333333333, 'r': 0.42857142857142855}, 'rouge-2': {'f': 0.24999999531250006, 'p': 0.2, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.36380597014857974, 'p': 0.3333333333333333, 'r': 0.42857142857142855}}]
#
# Text :  hong kong s largest energy company china light and power lrb clp rrb is looking to invest in a liquefied natural gas processing plant on the mainland reports said on friday <EOS>
#  Actual Summary :  hong kong energy giant plans to invest in china power plant
#  System Summary :  hong kong s new to meet for new quarter in iraq s
#  [{'rouge-1': {'f': 0.3809523759637189, 'p': 0.4, 'r': 0.36363636363636365}, 'rouge-2': {'f': 0.09523809024943337, 'p': 0.09090909090909091, 'r': 0.1}, 'rouge-l': {'f': 0.37923637923598086, 'p': 0.4, 'r': 0.36363636363636365}}]
#
# Text :  republican vice presidential hopeful sarah palin sent her son off to fight for a `` righteous cause thursday as his army unit prepared to deploy to iraq <EOS>
#  Actual Summary :  palin sends son to fight righteous cause in iraq
#  System Summary :  us pm to visit for myanmar of iraq s us oil in
#  [{'rouge-1': {'f': 0.2999999950500001, 'p': 0.2727272727272727, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.19611650485371557, 'p': 0.18181818181818182, 'r': 0.2222222222222222}}]
#
# Text :  philippine share prices closed percent lower on friday amid renewed apprehension about inflation and the local currency as well as credit problems in the united states dealers said <EOS>
#  Actual Summary :  philippine shares close percent lower
#  System Summary :  philippine shares close lower on oil price prices rise on oil prices
#  [{'rouge-1': {'f': 0.5714285668367348, 'p': 0.4444444444444444, 'r': 0.8}, 'rouge-2': {'f': 0.2857142816326531, 'p': 0.2, 'r': 0.5}, 'rouge-l': {'f': 0.4964871194372982, 'p': 0.4444444444444444, 'r': 0.8}}]
#
# Text :  philippine share prices closed percent lower on friday amid renewed apprehension about inflation and the local currency and credit problems in the united states dealers said <EOS>
#  Actual Summary :  philippine shares close percent lower
#  System Summary :  philippine shares close lower on oil oil prices rise on oil prices
#  [{'rouge-1': {'f': 0.6153846106508877, 'p': 0.5, 'r': 0.8}, 'rouge-2': {'f': 0.3076923034319527, 'p': 0.2222222222222222, 'r': 0.5}, 'rouge-l': {'f': 0.5588697017261648, 'p': 0.5, 'r': 0.8}}]
#
# Text :  malaysia s opposition admitted it might not meet its goal of seizing power by next week as it sent a delegation to pursue potential defectors from the government on a trip to taiwan <EOS>
#  Actual Summary :  malaysian opposition pursues mps to taiwan
#  System Summary :  taiwan s new to meet for new dollars in iraq s iraq
#  [{'rouge-1': {'f': 0.2666666618666667, 'p': 0.2222222222222222, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.12380952380883321, 'p': 0.1111111111111111, 'r': 0.16666666666666666}}]
#
# Text :  new zealand s prime minister helen clark called general elections for november friday with her labor party behind in opinion polls amid a slowing economy and her foreign minister facing the axe <EOS>
#  Actual Summary :  new zealand pm sets november date for general election
#  System Summary :  new zealand minister to visit for myanmar of iraq s us oil
#  [{'rouge-1': {'f': 0.2857142808163266, 'p': 0.25, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.1052631530193908, 'p': 0.09090909090909091, 'r': 0.125}, 'rouge-l': {'f': 0.2747252747245908, 'p': 0.25, 'r': 0.3333333333333333}}]
#
# Text :  growth in china s industrial output eased to percent in august from a year earlier the government said on friday providing further evidence the nation s economy is slowing <EOS>
#  Actual Summary :  china industrial output growth eases to pct
#  System Summary :  china s us to meet for us in iraq s iraq s
#  [{'rouge-1': {'f': 0.266666661688889, 'p': 0.25, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2643274853795029, 'p': 0.25, 'r': 0.2857142857142857}}]
#
# Text :  world oil prices climbed in asian trade friday as powerful hurricane ike hammered the southern us coast forcing the shutdown of oil and gas production facilities in the area dealers said <EOS>
#  Actual Summary :  oil prices up as hurricane ike barrels down on texas coast
#  System Summary :  oil shares close percent lower on oil oil prices prices lower on
#  [{'rouge-1': {'f': 0.3333333285802469, 'p': 0.42857142857142855, 'r': 0.2727272727272727}, 'rouge-2': {'f': 0.09999999500000027, 'p': 0.1, 'r': 0.1}, 'rouge-l': {'f': 0.30465949820784255, 'p': 0.42857142857142855, 'r': 0.2727272727272727}}]
#
# Text :  chinese share prices were slightly higher friday morning led by the electricity companies amid expectations the government may raise power prices soon dealers said <EOS>
#  Actual Summary :  chinese shares slightly higher in morning trade
#  System Summary :  chinese shares close lower on oil prices prices lower on oil prices
#  [{'rouge-1': {'f': 0.2857142807142858, 'p': 0.2857142857142857, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.14285713795918387, 'p': 0.125, 'r': 0.16666666666666666}, 'rouge-l': {'f': 0.2857142857137857, 'p': 0.2857142857142857, 'r': 0.2857142857142857}}]
#
# Text :  the dollar was steady in asian trade friday as markets waited for further developments surrounding troubled lehman brothers and looked ahead to earnings results from us banks next week dealers said <EOS>
#  Actual Summary :  dollar steady in asia on pause in banking worries
#  System Summary :  dollar stocks close lower on oil oil prices rise on oil oil
#  [{'rouge-1': {'f': 0.24999999500000009, 'p': 0.25, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2499999999995, 'p': 0.25, 'r': 0.25}}]
#
# Text :  hong kong share prices opened percent down on friday tracking falls on china bourses dealers said <EOS>
#  Actual Summary :  hong kong shares open percent down
#  System Summary :  hong kong shares close lower lower on oil oil prices rise on
#  [{'rouge-1': {'f': 0.39999999520000007, 'p': 0.3333333333333333, 'r': 0.5}, 'rouge-2': {'f': 0.2499999957031251, 'p': 0.18181818181818182, 'r': 0.4}, 'rouge-l': {'f': 0.3714285714278808, 'p': 0.3333333333333333, 'r': 0.5}}]
#
# Text :  growth in china s industrial output slowed to percent in august from a year earlier the national bureau of statistics said on friday <EOS>
#  Actual Summary :  china industrial output growth eases to pct
#  System Summary :  china s new to meet for us in iraq s iraq s
#  [{'rouge-1': {'f': 0.24999999507812506, 'p': 0.2222222222222222, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.24253731343216184, 'p': 0.2222222222222222, 'r': 0.2857142857142857}}]
#
# Text :  south africa s ruling party chief jacob zuma whose supporters vowed to crush any opposition to his becoming president of the country will hear friday if corruption charges against him will go to court <EOS>
#  Actual Summary :  south africa s anc chief back in court friday on graft charges
#  System Summary :  south africa s new to meet for new quarter in iraq s
#  [{'rouge-1': {'f': 0.36363635867768596, 'p': 0.4, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.18181817681818196, 'p': 0.18181818181818182, 'r': 0.18181818181818182}, 'rouge-l': {'f': 0.35777126099676687, 'p': 0.4, 'r': 0.3333333333333333}}]
#
# Text :  pope benedict xvi begins his first visit to france on friday hoping to strengthen president nicolas sarkozy s call for a more positive view of christian values in europe <EOS>
#  Actual Summary :  pope begins visit to france with soul searching sarkozy
#  System Summary :  malaysia s new pm to visit up in iraq s iraq s
#  [{'rouge-1': {'f': 0.22222221722222232, 'p': 0.2222222222222222, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.1111111111106111, 'p': 0.1111111111111111, 'r': 0.1111111111111111}}]
#
# Text :  hong kong gold prices opened lower on friday at us dollars an ounce down from thursday s close of dollars <EOS>
#  Actual Summary :  hong kong gold opens lower
#  System Summary :  hong kong gold open lower lower on oil oil prices rise on
#  [{'rouge-1': {'f': 0.5714285668367348, 'p': 0.4444444444444444, 'r': 0.8}, 'rouge-2': {'f': 0.26666666275555556, 'p': 0.18181818181818182, 'r': 0.5}, 'rouge-l': {'f': 0.4964871194372982, 'p': 0.4444444444444444, 'r': 0.8}}]
#
# Text :  hundreds of thousands of people fled thursday in a mandatory evacuation of parts of houston jamming roads leading away from the fourth largest us city and the us gulf coast as deadly hurricane ike bore down on texas <EOS>
#  Actual Summary :  thousands flee houston as deadly hurricane nears us coast
#  System Summary :  thousands of us in iraq s iraq s iraq s <unk> s
#  [{'rouge-1': {'f': 0.24999999507812506, 'p': 0.2857142857142857, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.24253731343261095, 'p': 0.2857142857142857, 'r': 0.2222222222222222}}]
#
# Text :  the us congress said thursday it would examine a landmark civilian nuclear agreement with india sent for approval by the white house as leaders of the two countries prepared to meet this month <EOS>
#  Actual Summary :  us congress vows to examine nuclear deal with india
#  System Summary :  us of us to be in iraq s iraq s iraq s
#  [{'rouge-1': {'f': 0.24999999507812506, 'p': 0.2857142857142857, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.24253731343261095, 'p': 0.2857142857142857, 'r': 0.2222222222222222}}]
#
# Text :  venezuelan president hugo chavez on thursday ordered the us ambassador to leave the country within hours in an act of solidarity with bolivia which also expelled its us envoy <EOS>
#  Actual Summary :  venezuela expels us ambassador in solidarity with bolivia
#  System Summary :  oil s new to meet for us in iraq s iraq s
#  [{'rouge-1': {'f': 0.23529411266435996, 'p': 0.2222222222222222, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.23368251410092805, 'p': 0.2222222222222222, 'r': 0.25}}]
#
# Text :  rescuers sunday searched hurricane ike s trail of destruction and floods for survivors with fears mounting of a gasoline crunch after the monster storm hammered the us oil hub and left millions without power <EOS>
#  Actual Summary :  search widens for survivors of ike
#  System Summary :  french pm to visit for myanmar of iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.2666666618666667, 'p': 0.2222222222222222, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.247619047618357, 'p': 0.2222222222222222, 'r': 0.3333333333333333}}]
#
# Text :  two american soldiers died on sunday in iraq of non combat related injuries the us military said <EOS>
#  Actual Summary :  two us soldiers die from non combat injuries in iraq
#  System Summary :  us police in china for iraq s iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.3529411716262976, 'p': 0.42857142857142855, 'r': 0.3}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.33283693224113053, 'p': 0.42857142857142855, 'r': 0.3}}]
#
# Text :  two american soldiers died on sunday in iraq of non combat related injuries the us military said without offering details <EOS>
#  Actual Summary :  two us soldiers die from non combat injuries in iraq
#  System Summary :  us police to be in china s iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.33333332839506175, 'p': 0.375, 'r': 0.3}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.32539682539657, 'p': 0.375, 'r': 0.3}}]
#
# Text :  rescuers sunday searched hurricane ike s trail of destruction and floods for survivors with fears mounting of a gasoline crunch after the monster storm hammered the us oil hub and left millions without power <EOS>
#  Actual Summary :  search for survivors of ike as recovery effort begins
#  System Summary :  french pm to visit for myanmar of iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.22222221722222232, 'p': 0.2222222222222222, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.22222222222172225, 'p': 0.2222222222222222, 'r': 0.2222222222222222}}]
#
# Text :  prosecutors called on sunday for a us soldier to face court martial for the murder of an iraqi detainee after two days of testimony at a pre trial hearing <EOS>
#  Actual Summary :  prosecutors want us soldier court martialled over iraq murder
#  System Summary :  iraq s us to meet for us in iraq s iraq s
#  [{'rouge-1': {'f': 0.24999999507812506, 'p': 0.2857142857142857, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.24253731343261095, 'p': 0.2857142857142857, 'r': 0.2222222222222222}}]
#
# Text :  russian foreign minister sergei lavrov embarked sunday on a diplomatic tour of the breakaway georgian regions at the center of last month s five day war <EOS>
#  Actual Summary :  russia s lavrov in post war tour of georgian <unk>
#  System Summary :  new zealand to visit in iraq s iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.23529411280276827, 'p': 0.2857142857142857, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11094564408029664, 'p': 0.14285714285714285, 'r': 0.1}}]
#
# Text :  an iraqi translator told a us soldier s pre trial hearing on sunday of the gruesome murder of a detainee who was shot and later had his face disfigured by an incendiary grenade <EOS>
#  Actual Summary :  iraqi translator tells us soldier s hearing of gruesome murder
#  System Summary :  us president to meet for us in iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.22222221728395072, 'p': 0.25, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.21693121693096162, 'p': 0.25, 'r': 0.2}}]
#
# Text :  pakistan vowed sunday to defend itself against violations of its air space and incursions by us forces in afghanistan <EOS>
#  Actual Summary :  pakistan vows to defend itself against us incursions
#  System Summary :  iran s new to meet for us in iraq s iraq s
#  [{'rouge-1': {'f': 0.23529411266435996, 'p': 0.2222222222222222, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.23368251410092805, 'p': 0.2222222222222222, 'r': 0.25}}]
#
# Text :  russian foreign minister sergei lavrov embarked sunday on a diplomatic tour of the breakaway georgian regions at the center of last month s five day war <EOS>
#  Actual Summary :  russia s lavrov in post war tour of georgian <unk>
#  System Summary :  new zealand to visit in iraq s iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.23529411280276827, 'p': 0.2857142857142857, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11094564408029664, 'p': 0.14285714285714285, 'r': 0.1}}]
#
# Text :  a court judgment implying south african president thabo mbeki s government meddled in a graft case against his chief rival will be discussed by the ruling party this week officials said sunday <EOS>
#  Actual Summary :  mbeki s fate under debate after safrican court ruling
#  System Summary :  us court to meet in iraq s iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.24999999507812506, 'p': 0.2857142857142857, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.12126865671619304, 'p': 0.14285714285714285, 'r': 0.1111111111111111}}]
#
# Text :  pakistan s new president asif ali zardari will discuss the conflict with taliban and al qaeda militants in the northern tribal areas with british leaders this week officials said sunday <EOS>
#  Actual Summary :  zardari to discuss al qaeda conflict in britain
#  System Summary :  malaysia s <unk> s new president to visit in iraq s iraq
#  [{'rouge-1': {'f': 0.23529411266435996, 'p': 0.2222222222222222, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.23368251410092805, 'p': 0.2222222222222222, 'r': 0.25}}]
#
# Text :  president george w bush said on sunday he would travel to texas on tuesday to offer sympathy and government support to those affected by hurricane ike which caused flooding and damage after striking the us gulf coast on saturday <EOS>
#  Actual Summary :  bush to visit texas on tuesday
#  System Summary :  south africa s us to visit for us in iraq s iraq
#  [{'rouge-1': {'f': 0.2666666618666667, 'p': 0.2222222222222222, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.12499999570312517, 'p': 0.09090909090909091, 'r': 0.2}, 'rouge-l': {'f': 0.247619047618357, 'p': 0.2222222222222222, 'r': 0.3333333333333333}}]
#
# Text :  iraq s parliament on sunday lifted the immunity of sunni lawmaker <UNK> <unk> for visiting israel last week to attend an international conference to fight terrorism an afp correspondent reported <EOS>
#  Actual Summary :  iraq parliament lifts immunity of sunni mp over israel visit
#  System Summary :  iran s china to visit in iraq s iraq s iraq s
#  [{'rouge-1': {'f': 0.23529411280276827, 'p': 0.2857142857142857, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11094564408029664, 'p': 0.14285714285714285, 'r': 0.1}}]
#
# Text :  a bomb blast sunday in central afghanistan killed six children and wounded some of them critically a local official said <EOS>
#  Actual Summary :  bomb blast kills six children in afghanistan
#  System Summary :  us soldier in iraq of iraq in iraq blast blast in iraq
#  [{'rouge-1': {'f': 0.3076923027218935, 'p': 0.3333333333333333, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.3041144901606695, 'p': 0.3333333333333333, 'r': 0.2857142857142857}}]
#
# Text :  a bomb blast sunday in central afghanistan killed six children and wounded some of them critically a local official said <EOS>
#  Actual Summary :  bomb blast kills six children in afghanistan
#  System Summary :  us soldier in iraq of iraq in iraq blast blast in iraq
#  [{'rouge-1': {'f': 0.3076923027218935, 'p': 0.3333333333333333, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.3041144901606695, 'p': 0.3333333333333333, 'r': 0.2857142857142857}}]
#
# Text :  zimbabwe s leaders are set to sign a historic deal monday to divide power among political rivals after months of ruinous standoff between president robert mugabe and the opposition <EOS>
#  Actual Summary :  zimbabwe s political rivals set to sign crisis deal
#  System Summary :  malaysia s new pm to visit up dollars in iraq s iraq
#  [{'rouge-1': {'f': 0.21052631080332423, 'p': 0.2, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.20936957779003676, 'p': 0.2, 'r': 0.2222222222222222}}]
#
# Text :  an iraqi translator told a us soldier s pre trial hearing on sunday about the gruesome murder of a detainee who was shot and later had his face disfigured by an incendiary grenade <EOS>
#  Actual Summary :  iraqi translator tells us soldier s hearing of gruesome murder
#  System Summary :  us president to meet for us in iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.22222221728395072, 'p': 0.25, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.21693121693096162, 'p': 0.25, 'r': 0.2}}]
#
# Text :  us president george w bush was set to meet with his top disaster relief aides sunday to discuss assistance to victims of hurricane ike the white house said <EOS>
#  Actual Summary :  bush to discuss aid to victims in wake of hurricane ike
#  System Summary :  bush s us to meet in iraq s iraq s iraq s
#  [{'rouge-1': {'f': 0.3529411716262976, 'p': 0.42857142857142855, 'r': 0.3}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.33283693224113053, 'p': 0.42857142857142855, 'r': 0.3}}]
#
# Text :  more witnesses are set to testify on sunday against a us soldier on the second day of a pre trial hearing on charges of murdering an iraqi detainee by shooting him and then burning him with an incendiary grenade <EOS>
#  Actual Summary :  more witnesses to testify against us soldier after murder of iraqi
#  System Summary :  us of us in iraq s iraq s us in iraq s
#  [{'rouge-1': {'f': 0.2499999957031251, 'p': 0.4, 'r': 0.18181818181818182}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2005494505495442, 'p': 0.4, 'r': 0.18181818181818182}}]
#
# Text :  pakistan s new president asif ali zardari will discuss the conflict with taliban and al qaeda militants in the northern tribal areas with british leaders this week officials said sunday <EOS>
#  Actual Summary :  zardari to discuss al qaeda conflict in britain
#  System Summary :  malaysia s <unk> s new president to visit in iraq s iraq
#  [{'rouge-1': {'f': 0.23529411266435996, 'p': 0.2222222222222222, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.23368251410092805, 'p': 0.2222222222222222, 'r': 0.25}}]
#
# Text :  the serial blasts in the indian capital of new delhi which left dead and injured were the latest in a string of attacks to hit the country in recent years <EOS>
#  Actual Summary :  chronology of recent bomb attacks in india
#  System Summary :  us soldier in iraq of iraq of iraq s iraq s iraq
#  [{'rouge-1': {'f': 0.3076923027218935, 'p': 0.3333333333333333, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.15205724508016866, 'p': 0.16666666666666666, 'r': 0.14285714285714285}}]
#
# Text :  us president george w bush was set to meet with his top disaster relief aides sunday to discuss assistance to victims of hurricane ike the white house said <EOS>
#  Actual Summary :  bush to discuss aid to victims in wake of hurricane ike
#  System Summary :  bush s us to meet in iraq s iraq s iraq s
#  [{'rouge-1': {'f': 0.3529411716262976, 'p': 0.42857142857142855, 'r': 0.3}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.33283693224113053, 'p': 0.42857142857142855, 'r': 0.3}}]

# %% [markdown]
# ##Training Overall Results

# %%
checkpoint = "final_best_model_multigraph.ckpt" 
with tf.Session(graph=train_graph) as sess:
  saver = tf.train.Saver()
  saver.restore(sess,os.path.join(ckpt_path,type_val,checkpoint))
  train_logits = []
  for batch_i, (summaries_batch, texts_batch, summaries_lengths, texts_lengths) in enumerate(
          get_batches(train_summaries, train_texts, params['batch_size'])):
    ilog = sess.run( ob.inference_logits,
          {ob.encoder_inputs: texts_batch,
           ob.decoder_targets: summaries_batch,
           ob.learning_rate: learning_rate,
           ob.decoder_lengths: summaries_lengths,
           ob.encoder_lengths: texts_lengths})
    print("Batch No. %d of %d"%(batch_i+1,int(len(train_summaries)/params['batch_size'])))
    train_logits.extend(ilog.tolist())
  rouge = Rouge()
  all_pred, all_summ = [], []
  for i in range(len(train_logits)):
    pred = " ".join([int_to_vocab[train_logits[i][k]] if train_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(train_logits[i]))])
    true = " ".join([int_to_vocab[train_summaries[i][k]] if train_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(train_summaries[i]))])
    all_pred.append(pred)
    all_summ.append(true)
  print("Average Rouge Socres :", rouge.get_scores(all_pred, all_summ, avg = True))
# Out:
# INFO:tensorflow:Restoring parameters from gdrive/My Drive/Ab_Summarization/Our_Own_Code/Model_Check_Points/final_best_model.ckpt
# Batch No. 1 of 10937
# Batch No. 2 of 10937
# Batch No. 3 of 10937
# Batch No. 4 of 10937
# Batch No. 5 of 10937
# Batch No. 6 of 10937
# Batch No. 7 of 10937
# Batch No. 8 of 10937
# Batch No. 9 of 10937
# Batch No. 10 of 10937
# Batch No. 11 of 10937
# Batch No. 12 of 10937
# Batch No. 13 of 10937
# Batch No. 14 of 10937
# Batch No. 15 of 10937
# Batch No. 16 of 10937
# Batch No. 17 of 10937
# Batch No. 18 of 10937
# Batch No. 19 of 10937
# Batch No. 20 of 10937
# Batch No. 21 of 10937
# Batch No. 22 of 10937
# Batch No. 23 of 10937
# Batch No. 24 of 10937
# Batch No. 25 of 10937
# Batch No. 26 of 10937
# Batch No. 27 of 10937
# Batch No. 28 of 10937
# Batch No. 29 of 10937
# Batch No. 30 of 10937
# Batch No. 31 of 10937
# Batch No. 32 of 10937
# Batch No. 33 of 10937
# Batch No. 34 of 10937
# Batch No. 35 of 10937
# Batch No. 36 of 10937
# Batch No. 37 of 10937
# Batch No. 38 of 10937
# Batch No. 39 of 10937
# Batch No. 40 of 10937
# Batch No. 41 of 10937
# Batch No. 42 of 10937
# Batch No. 43 of 10937
# Batch No. 44 of 10937
# Batch No. 45 of 10937
# Batch No. 46 of 10937
# Batch No. 47 of 10937
# Batch No. 48 of 10937
# Batch No. 49 of 10937
# Batch No. 50 of 10937
# Batch No. 51 of 10937
# Batch No. 52 of 10937
# Batch No. 53 of 10937
# Batch No. 54 of 10937
# Batch No. 55 of 10937
# Batch No. 56 of 10937
# Batch No. 57 of 10937
# Batch No. 58 of 10937
# Batch No. 59 of 10937
# Batch No. 60 of 10937
# Batch No. 61 of 10937
# Batch No. 62 of 10937
# Batch No. 63 of 10937
# Batch No. 64 of 10937
# Batch No. 65 of 10937
# Batch No. 66 of 10937
# Batch No. 67 of 10937
# Batch No. 68 of 10937
# Batch No. 69 of 10937
# Batch No. 70 of 10937
# Batch No. 71 of 10937
# Batch No. 72 of 10937
# Batch No. 73 of 10937
# Batch No. 74 of 10937
# Batch No. 75 of 10937
# Batch No. 76 of 10937
# Batch No. 77 of 10937
# Batch No. 78 of 10937
# Batch No. 79 of 10937
# Batch No. 80 of 10937
# Batch No. 81 of 10937
# Batch No. 82 of 10937
# Batch No. 83 of 10937
# Batch No. 84 of 10937
# Batch No. 85 of 10937
# Batch No. 86 of 10937
# Batch No. 87 of 10937
# Batch No. 88 of 10937
# Batch No. 89 of 10937
# Batch No. 90 of 10937
# Batch No. 91 of 10937
# Batch No. 92 of 10937
# Batch No. 93 of 10937
# Batch No. 94 of 10937
# Batch No. 95 of 10937
# Batch No. 96 of 10937
# Batch No. 97 of 10937
# Batch No. 98 of 10937
# Batch No. 99 of 10937
# Batch No. 100 of 10937
# Batch No. 101 of 10937
# Batch No. 102 of 10937
# Batch No. 103 of 10937
# Batch No. 104 of 10937
# Batch No. 105 of 10937
# Batch No. 106 of 10937
# Batch No. 107 of 10937
# Batch No. 108 of 10937
# Batch No. 109 of 10937
# Batch No. 110 of 10937
# Batch No. 111 of 10937
# Batch No. 112 of 10937
# Batch No. 113 of 10937
# Batch No. 114 of 10937
# Batch No. 115 of 10937
# Batch No. 116 of 10937
# Batch No. 117 of 10937
# Batch No. 118 of 10937
# Batch No. 119 of 10937
# Batch No. 120 of 10937
# Batch No. 121 of 10937
# Batch No. 122 of 10937
# Batch No. 123 of 10937
# Batch No. 124 of 10937
# Batch No. 125 of 10937
# Batch No. 126 of 10937
# Batch No. 127 of 10937
# Batch No. 128 of 10937
# Batch No. 129 of 10937
# Batch No. 130 of 10937
# Batch No. 131 of 10937
# Batch No. 132 of 10937
# Batch No. 133 of 10937
# Batch No. 134 of 10937
# Batch No. 135 of 10937
# Batch No. 136 of 10937
# Batch No. 137 of 10937
# Batch No. 138 of 10937
# Batch No. 139 of 10937
# Batch No. 140 of 10937
# Batch No. 141 of 10937
# Batch No. 142 of 10937
# Batch No. 143 of 10937
# Batch No. 144 of 10937
# Batch No. 145 of 10937
# Batch No. 146 of 10937
# Batch No. 147 of 10937
# Batch No. 148 of 10937
# Batch No. 149 of 10937
# Batch No. 150 of 10937
# Batch No. 151 of 10937
# Batch No. 152 of 10937
# Batch No. 153 of 10937
# Batch No. 154 of 10937
# Batch No. 155 of 10937
# Batch No. 156 of 10937
# Batch No. 157 of 10937
# Batch No. 158 of 10937
# Batch No. 159 of 10937
# Batch No. 160 of 10937
# Batch No. 161 of 10937
# Batch No. 162 of 10937
# Batch No. 163 of 10937
# Batch No. 164 of 10937
# Batch No. 165 of 10937
# Batch No. 166 of 10937
# Batch No. 167 of 10937
# Batch No. 168 of 10937
# Batch No. 169 of 10937
# Batch No. 170 of 10937
# Batch No. 171 of 10937
# Batch No. 172 of 10937
# Batch No. 173 of 10937
# Batch No. 174 of 10937
# Batch No. 175 of 10937
# Batch No. 176 of 10937
# Batch No. 177 of 10937
# Batch No. 178 of 10937
# Batch No. 179 of 10937
# Batch No. 180 of 10937
# Batch No. 181 of 10937
# Batch No. 182 of 10937
# Batch No. 183 of 10937
# Batch No. 184 of 10937
# Batch No. 185 of 10937
# Batch No. 186 of 10937
# Batch No. 187 of 10937
# Batch No. 188 of 10937
# Batch No. 189 of 10937
# Batch No. 190 of 10937
# Batch No. 191 of 10937
# Batch No. 192 of 10937
# Batch No. 193 of 10937
# Batch No. 194 of 10937
# Batch No. 195 of 10937
# Batch No. 196 of 10937
# Batch No. 197 of 10937
# Batch No. 198 of 10937
# Batch No. 199 of 10937
# Batch No. 200 of 10937
# Batch No. 201 of 10937
# Batch No. 202 of 10937
# Batch No. 203 of 10937
# Batch No. 204 of 10937
# Batch No. 205 of 10937
# Batch No. 206 of 10937
# Batch No. 207 of 10937
# Batch No. 208 of 10937
# Batch No. 209 of 10937
# Batch No. 210 of 10937
# Batch No. 211 of 10937
# Batch No. 212 of 10937
# Batch No. 213 of 10937
# Batch No. 214 of 10937
# Batch No. 215 of 10937
# Batch No. 216 of 10937
# Batch No. 217 of 10937
# Batch No. 218 of 10937
# Batch No. 219 of 10937
# Batch No. 220 of 10937
# Batch No. 221 of 10937
# Batch No. 222 of 10937
# Batch No. 223 of 10937
# Batch No. 224 of 10937
# Batch No. 225 of 10937
# Batch No. 226 of 10937
# Batch No. 227 of 10937
# Batch No. 228 of 10937
# Batch No. 229 of 10937
# Batch No. 230 of 10937
# Batch No. 231 of 10937
# Batch No. 232 of 10937
# Batch No. 233 of 10937
# Batch No. 234 of 10937
# Batch No. 235 of 10937
# Batch No. 236 of 10937
# Batch No. 237 of 10937
# Batch No. 238 of 10937
# Batch No. 239 of 10937
# Batch No. 240 of 10937
# Batch No. 241 of 10937
# Batch No. 242 of 10937
# Batch No. 243 of 10937
# Batch No. 244 of 10937
# Batch No. 245 of 10937
# Batch No. 246 of 10937
# Batch No. 247 of 10937
# Batch No. 248 of 10937
# Batch No. 249 of 10937
# Batch No. 250 of 10937
# Batch No. 251 of 10937
# Batch No. 252 of 10937
# Batch No. 253 of 10937
# Batch No. 254 of 10937
# Batch No. 255 of 10937
# Batch No. 256 of 10937
# Batch No. 257 of 10937
# Batch No. 258 of 10937
# Batch No. 259 of 10937
# Batch No. 260 of 10937
# Batch No. 261 of 10937
# Batch No. 262 of 10937
# Batch No. 263 of 10937
# Batch No. 264 of 10937
# Batch No. 265 of 10937
# Batch No. 266 of 10937
# Batch No. 267 of 10937
# Batch No. 268 of 10937
# Batch No. 269 of 10937
# Batch No. 270 of 10937
# Batch No. 271 of 10937
# Batch No. 272 of 10937
# Batch No. 273 of 10937
# Batch No. 274 of 10937
# Batch No. 275 of 10937
# Batch No. 276 of 10937
# Batch No. 277 of 10937
# Batch No. 278 of 10937
# Batch No. 279 of 10937
# Batch No. 280 of 10937
# Batch No. 281 of 10937
# Batch No. 282 of 10937
# Batch No. 283 of 10937
# Batch No. 284 of 10937
# Batch No. 285 of 10937
# Batch No. 286 of 10937
# Batch No. 287 of 10937
# Batch No. 288 of 10937
# Batch No. 289 of 10937
# Batch No. 290 of 10937
# Batch No. 291 of 10937
# Batch No. 292 of 10937
# Batch No. 293 of 10937
# Batch No. 294 of 10937
# Batch No. 295 of 10937
# Batch No. 296 of 10937
# Batch No. 297 of 10937
# Batch No. 298 of 10937
# Batch No. 299 of 10937
# Batch No. 300 of 10937
# Batch No. 301 of 10937
# Batch No. 302 of 10937
# Batch No. 303 of 10937
# Batch No. 304 of 10937
# Batch No. 305 of 10937
# Batch No. 306 of 10937
# Batch No. 307 of 10937
# Batch No. 308 of 10937
# Batch No. 309 of 10937
# Batch No. 310 of 10937
# Batch No. 311 of 10937
# Batch No. 312 of 10937
# Batch No. 313 of 10937
# Batch No. 314 of 10937
# Batch No. 315 of 10937
# Batch No. 316 of 10937
# Batch No. 317 of 10937
# Batch No. 318 of 10937
# Batch No. 319 of 10937
# Batch No. 320 of 10937
# Batch No. 321 of 10937
# Batch No. 322 of 10937
# Batch No. 323 of 10937
# Batch No. 324 of 10937
# Batch No. 325 of 10937
# Batch No. 326 of 10937
# Batch No. 327 of 10937
# Batch No. 328 of 10937
# Batch No. 329 of 10937
# Batch No. 330 of 10937
# Batch No. 331 of 10937
# Batch No. 332 of 10937
# Batch No. 333 of 10937
# Batch No. 334 of 10937
# Batch No. 335 of 10937
# Batch No. 336 of 10937
# Batch No. 337 of 10937
# Batch No. 338 of 10937
# Batch No. 339 of 10937
# Batch No. 340 of 10937
# Batch No. 341 of 10937
# Batch No. 342 of 10937
# Batch No. 343 of 10937
# Batch No. 344 of 10937
# Batch No. 345 of 10937
# Batch No. 346 of 10937
# Batch No. 347 of 10937
# Batch No. 348 of 10937
# Batch No. 349 of 10937
# Batch No. 350 of 10937
# Batch No. 351 of 10937
# Batch No. 352 of 10937
# Batch No. 353 of 10937
# Batch No. 354 of 10937
# Batch No. 355 of 10937
# Batch No. 356 of 10937
# Batch No. 357 of 10937
# Batch No. 358 of 10937
# Batch No. 359 of 10937
# Batch No. 360 of 10937
# Batch No. 361 of 10937
# Batch No. 362 of 10937
# Batch No. 363 of 10937
# Batch No. 364 of 10937
# Batch No. 365 of 10937
# Batch No. 366 of 10937
# Batch No. 367 of 10937
# Batch No. 368 of 10937
# Batch No. 369 of 10937
# Batch No. 370 of 10937
# Batch No. 371 of 10937
# Batch No. 372 of 10937
# Batch No. 373 of 10937
# Batch No. 374 of 10937
# Batch No. 375 of 10937
# Batch No. 376 of 10937
# Batch No. 377 of 10937
# Batch No. 378 of 10937
# Batch No. 379 of 10937
# Batch No. 380 of 10937
# Batch No. 381 of 10937
# Batch No. 382 of 10937
# Batch No. 383 of 10937
# Batch No. 384 of 10937
# Batch No. 385 of 10937
# Batch No. 386 of 10937
# Batch No. 387 of 10937
# Batch No. 388 of 10937
# Batch No. 389 of 10937
# Batch No. 390 of 10937
# Batch No. 391 of 10937
# Batch No. 392 of 10937
# Batch No. 393 of 10937
# Batch No. 394 of 10937
# Batch No. 395 of 10937
# Batch No. 396 of 10937
# Batch No. 397 of 10937
# Batch No. 398 of 10937
# Batch No. 399 of 10937
# Batch No. 400 of 10937
# Batch No. 401 of 10937
# Batch No. 402 of 10937
# Batch No. 403 of 10937
# Batch No. 404 of 10937
# Batch No. 405 of 10937
# Batch No. 406 of 10937
# Batch No. 407 of 10937
# Batch No. 408 of 10937
# Batch No. 409 of 10937
# Batch No. 410 of 10937
# Batch No. 411 of 10937
# Batch No. 412 of 10937
# Batch No. 413 of 10937
# Batch No. 414 of 10937
# Batch No. 415 of 10937
# Batch No. 416 of 10937
# Batch No. 417 of 10937
# Batch No. 418 of 10937
# Batch No. 419 of 10937
# Batch No. 420 of 10937
# Batch No. 421 of 10937
# Batch No. 422 of 10937
# Batch No. 423 of 10937
# Batch No. 424 of 10937
# Batch No. 425 of 10937
# Batch No. 426 of 10937
# Batch No. 427 of 10937
# Batch No. 428 of 10937
# Batch No. 429 of 10937
# Batch No. 430 of 10937
# Batch No. 431 of 10937
# Batch No. 432 of 10937
# Batch No. 433 of 10937
# Batch No. 434 of 10937
# Batch No. 435 of 10937
# Batch No. 436 of 10937
# Batch No. 437 of 10937
# Batch No. 438 of 10937
# Batch No. 439 of 10937
# Batch No. 440 of 10937
# Batch No. 441 of 10937
# Batch No. 442 of 10937
# Batch No. 443 of 10937
# Batch No. 444 of 10937
# Batch No. 445 of 10937
# Batch No. 446 of 10937
# Batch No. 447 of 10937
# Batch No. 448 of 10937
# Batch No. 449 of 10937
# Batch No. 450 of 10937
# Batch No. 451 of 10937
# Batch No. 452 of 10937
# Batch No. 453 of 10937
# Batch No. 454 of 10937
# Batch No. 455 of 10937
# Batch No. 456 of 10937
# Batch No. 457 of 10937
# Batch No. 458 of 10937
# Batch No. 459 of 10937
# Batch No. 460 of 10937
# Batch No. 461 of 10937
# Batch No. 462 of 10937
# Batch No. 463 of 10937
# Batch No. 464 of 10937
# Batch No. 465 of 10937
# Batch No. 466 of 10937
# Batch No. 467 of 10937
# Batch No. 468 of 10937
# Batch No. 469 of 10937
# Batch No. 470 of 10937
# Batch No. 471 of 10937
# Batch No. 472 of 10937
# Batch No. 473 of 10937
# Batch No. 474 of 10937
# Batch No. 475 of 10937
# Batch No. 476 of 10937
# Batch No. 477 of 10937
# Batch No. 478 of 10937
# Batch No. 479 of 10937
# Batch No. 480 of 10937
# Batch No. 481 of 10937
# Batch No. 482 of 10937
# Batch No. 483 of 10937
# Batch No. 484 of 10937
# Batch No. 485 of 10937
# Batch No. 486 of 10937
# Batch No. 487 of 10937
# Batch No. 488 of 10937
# Batch No. 489 of 10937
# Batch No. 490 of 10937
# Batch No. 491 of 10937
# Batch No. 492 of 10937
# Batch No. 493 of 10937
# Batch No. 494 of 10937
# Batch No. 495 of 10937
# Batch No. 496 of 10937
# Batch No. 497 of 10937
# Batch No. 498 of 10937
# Batch No. 499 of 10937
# Batch No. 500 of 10937
# Batch No. 501 of 10937
# Batch No. 502 of 10937
# Batch No. 503 of 10937
# Batch No. 504 of 10937
# Batch No. 505 of 10937
# Batch No. 506 of 10937
# Batch No. 507 of 10937
# Batch No. 508 of 10937
# Batch No. 509 of 10937
# Batch No. 510 of 10937
# Batch No. 511 of 10937
# Batch No. 512 of 10937
# Batch No. 513 of 10937
# Batch No. 514 of 10937
# Batch No. 515 of 10937
# Batch No. 516 of 10937
# Batch No. 517 of 10937
# Batch No. 518 of 10937
# Batch No. 519 of 10937
# Batch No. 520 of 10937
# Batch No. 521 of 10937
# Batch No. 522 of 10937
# Batch No. 523 of 10937
# Batch No. 524 of 10937
# Batch No. 525 of 10937
# Batch No. 526 of 10937
# Batch No. 527 of 10937
# Batch No. 528 of 10937
# Batch No. 529 of 10937
# Batch No. 530 of 10937
# Batch No. 531 of 10937
# Batch No. 532 of 10937
# Batch No. 533 of 10937
# Batch No. 534 of 10937
# Batch No. 535 of 10937
# Batch No. 536 of 10937
# Batch No. 537 of 10937
# Batch No. 538 of 10937
# Batch No. 539 of 10937
# Batch No. 540 of 10937
# Batch No. 541 of 10937
# Batch No. 542 of 10937
# Batch No. 543 of 10937
# Batch No. 544 of 10937
# Batch No. 545 of 10937
# Batch No. 546 of 10937
# Batch No. 547 of 10937
# Batch No. 548 of 10937
# Batch No. 549 of 10937
# Batch No. 550 of 10937
# Batch No. 551 of 10937
# Batch No. 552 of 10937
# Batch No. 553 of 10937
# Batch No. 554 of 10937
# Batch No. 555 of 10937
# Batch No. 556 of 10937
# Batch No. 557 of 10937
# Batch No. 558 of 10937
# Batch No. 559 of 10937
# Batch No. 560 of 10937
# Batch No. 561 of 10937
# Batch No. 562 of 10937
# Batch No. 563 of 10937
# Batch No. 564 of 10937
# Batch No. 565 of 10937
# Batch No. 566 of 10937
# Batch No. 567 of 10937
# Batch No. 568 of 10937
# Batch No. 569 of 10937
# Batch No. 570 of 10937
# Batch No. 571 of 10937
# Batch No. 572 of 10937
# Batch No. 573 of 10937
# Batch No. 574 of 10937
# Batch No. 575 of 10937
# Batch No. 576 of 10937
# Batch No. 577 of 10937
# Batch No. 578 of 10937
# Batch No. 579 of 10937
# Batch No. 580 of 10937
# Batch No. 581 of 10937
# Batch No. 582 of 10937
# Batch No. 583 of 10937
# Batch No. 584 of 10937
# Batch No. 585 of 10937
# Batch No. 586 of 10937
# Batch No. 587 of 10937
# Batch No. 588 of 10937
# Batch No. 589 of 10937
# Batch No. 590 of 10937
# Batch No. 591 of 10937
# Batch No. 592 of 10937
# Batch No. 593 of 10937
# Batch No. 594 of 10937
# Batch No. 595 of 10937
# Batch No. 596 of 10937
# Batch No. 597 of 10937
# Batch No. 598 of 10937
# Batch No. 599 of 10937
# Batch No. 600 of 10937
# Batch No. 601 of 10937
# Batch No. 602 of 10937
# Batch No. 603 of 10937
# Batch No. 604 of 10937
# Batch No. 605 of 10937
# Batch No. 606 of 10937
# Batch No. 607 of 10937
# Batch No. 608 of 10937
# Batch No. 609 of 10937
# Batch No. 610 of 10937
# Batch No. 611 of 10937
# Batch No. 612 of 10937
# Batch No. 613 of 10937
# Batch No. 614 of 10937
# Batch No. 615 of 10937
# Batch No. 616 of 10937
# Batch No. 617 of 10937
# Batch No. 618 of 10937
# Batch No. 619 of 10937
# Batch No. 620 of 10937
# Batch No. 621 of 10937
# Batch No. 622 of 10937
# Batch No. 623 of 10937
# Batch No. 624 of 10937
# Batch No. 625 of 10937
# Batch No. 626 of 10937
# Batch No. 627 of 10937
# Batch No. 628 of 10937
# Batch No. 629 of 10937
# Batch No. 630 of 10937
# Batch No. 631 of 10937
# Batch No. 632 of 10937
# Batch No. 633 of 10937
# Batch No. 634 of 10937
# Batch No. 635 of 10937
# Batch No. 636 of 10937
# Batch No. 637 of 10937
# Batch No. 638 of 10937
# Batch No. 639 of 10937
# Batch No. 640 of 10937
# Batch No. 641 of 10937
# Batch No. 642 of 10937
# Batch No. 643 of 10937
# Batch No. 644 of 10937
# Batch No. 645 of 10937
# Batch No. 646 of 10937
# Batch No. 647 of 10937
# Batch No. 648 of 10937
# Batch No. 649 of 10937
# Batch No. 650 of 10937
# Batch No. 651 of 10937
# Batch No. 652 of 10937
# Batch No. 653 of 10937
# Batch No. 654 of 10937
# Batch No. 655 of 10937
# Batch No. 656 of 10937
# Batch No. 657 of 10937
# Batch No. 658 of 10937
# Batch No. 659 of 10937
# Batch No. 660 of 10937
# Batch No. 661 of 10937
# Batch No. 662 of 10937
# Batch No. 663 of 10937
# Batch No. 664 of 10937
# Batch No. 665 of 10937
# Batch No. 666 of 10937
# Batch No. 667 of 10937
# Batch No. 668 of 10937
# Batch No. 669 of 10937
# Batch No. 670 of 10937
# Batch No. 671 of 10937
# Batch No. 672 of 10937
# Batch No. 673 of 10937
# Batch No. 674 of 10937
# Batch No. 675 of 10937
# Batch No. 676 of 10937
# Batch No. 677 of 10937
# Batch No. 678 of 10937
# Batch No. 679 of 10937
# Batch No. 680 of 10937
# Batch No. 681 of 10937
# Batch No. 682 of 10937
# Batch No. 683 of 10937
# Batch No. 684 of 10937
# Batch No. 685 of 10937
# Batch No. 686 of 10937
# Batch No. 687 of 10937
# Batch No. 688 of 10937
# Batch No. 689 of 10937
# Batch No. 690 of 10937
# Batch No. 691 of 10937
# Batch No. 692 of 10937
# Batch No. 693 of 10937
# Batch No. 694 of 10937
# Batch No. 695 of 10937
# Batch No. 696 of 10937
# Batch No. 697 of 10937
# Batch No. 698 of 10937
# Batch No. 699 of 10937
# Batch No. 700 of 10937
# Batch No. 701 of 10937
# Batch No. 702 of 10937
# Batch No. 703 of 10937
# Batch No. 704 of 10937
# Batch No. 705 of 10937
# Batch No. 706 of 10937
# Batch No. 707 of 10937
# Batch No. 708 of 10937
# Batch No. 709 of 10937
# Batch No. 710 of 10937
# Batch No. 711 of 10937
# Batch No. 712 of 10937
# Batch No. 713 of 10937
# Batch No. 714 of 10937
# Batch No. 715 of 10937
# Batch No. 716 of 10937
# Batch No. 717 of 10937
# Batch No. 718 of 10937
# Batch No. 719 of 10937
# Batch No. 720 of 10937
# Batch No. 721 of 10937
# Batch No. 722 of 10937
# Batch No. 723 of 10937
# Batch No. 724 of 10937
# Batch No. 725 of 10937
# Batch No. 726 of 10937
# Batch No. 727 of 10937
# Batch No. 728 of 10937
# Batch No. 729 of 10937
# Batch No. 730 of 10937
# Batch No. 731 of 10937
# Batch No. 732 of 10937
# Batch No. 733 of 10937
# Batch No. 734 of 10937
# Batch No. 735 of 10937
# Batch No. 736 of 10937
# Batch No. 737 of 10937
# Batch No. 738 of 10937
# Batch No. 739 of 10937
# Batch No. 740 of 10937
# Batch No. 741 of 10937
# Batch No. 742 of 10937
# Batch No. 743 of 10937
# Batch No. 744 of 10937
# Batch No. 745 of 10937
# Batch No. 746 of 10937
# Batch No. 747 of 10937
# Batch No. 748 of 10937
# Batch No. 749 of 10937
# Batch No. 750 of 10937
# Batch No. 751 of 10937
# Batch No. 752 of 10937
# Batch No. 753 of 10937
# Batch No. 754 of 10937
# Batch No. 755 of 10937
# Batch No. 756 of 10937
# Batch No. 757 of 10937
# Batch No. 758 of 10937
# Batch No. 759 of 10937
# Batch No. 760 of 10937
# Batch No. 761 of 10937
# Batch No. 762 of 10937
# Batch No. 763 of 10937
# Batch No. 764 of 10937
# Batch No. 765 of 10937
# Batch No. 766 of 10937
# Batch No. 767 of 10937
# Batch No. 768 of 10937
# Batch No. 769 of 10937
# Batch No. 770 of 10937
# Batch No. 771 of 10937
# Batch No. 772 of 10937
# Batch No. 773 of 10937
# Batch No. 774 of 10937
# Batch No. 775 of 10937
# Batch No. 776 of 10937
# Batch No. 777 of 10937
# Batch No. 778 of 10937
# Batch No. 779 of 10937
# Batch No. 780 of 10937
# Batch No. 781 of 10937
# Batch No. 782 of 10937
# Batch No. 783 of 10937
# Batch No. 784 of 10937
# Batch No. 785 of 10937
# Batch No. 786 of 10937
# Batch No. 787 of 10937
# Batch No. 788 of 10937
# Batch No. 789 of 10937
# Batch No. 790 of 10937
# Batch No. 791 of 10937
# Batch No. 792 of 10937
# Batch No. 793 of 10937
# Batch No. 794 of 10937
# Batch No. 795 of 10937
# Batch No. 796 of 10937
# Batch No. 797 of 10937
# Batch No. 798 of 10937
# Batch No. 799 of 10937
# Batch No. 800 of 10937
# Batch No. 801 of 10937
# Batch No. 802 of 10937
# Batch No. 803 of 10937
# Batch No. 804 of 10937
# Batch No. 805 of 10937
# Batch No. 806 of 10937
# Batch No. 807 of 10937
# Batch No. 808 of 10937
# Batch No. 809 of 10937
# Batch No. 810 of 10937
# Batch No. 811 of 10937
# Batch No. 812 of 10937
# Batch No. 813 of 10937
# Batch No. 814 of 10937
# Batch No. 815 of 10937
# Batch No. 816 of 10937
# Batch No. 817 of 10937
# Batch No. 818 of 10937
# Batch No. 819 of 10937
# Batch No. 820 of 10937
# Batch No. 821 of 10937
# Batch No. 822 of 10937
# Batch No. 823 of 10937
# Batch No. 824 of 10937
# Batch No. 825 of 10937
# Batch No. 826 of 10937
# Batch No. 827 of 10937
# Batch No. 828 of 10937
# Batch No. 829 of 10937
# Batch No. 830 of 10937
# Batch No. 831 of 10937
# Batch No. 832 of 10937
# Batch No. 833 of 10937
# Batch No. 834 of 10937
# Batch No. 835 of 10937
# Batch No. 836 of 10937
# Batch No. 837 of 10937
# Batch No. 838 of 10937
# Batch No. 839 of 10937
# Batch No. 840 of 10937
# Batch No. 841 of 10937
# Batch No. 842 of 10937
# Batch No. 843 of 10937
# Batch No. 844 of 10937
# Batch No. 845 of 10937
# Batch No. 846 of 10937
# Batch No. 847 of 10937
# Batch No. 848 of 10937
# Batch No. 849 of 10937
# Batch No. 850 of 10937
# Batch No. 851 of 10937
# Batch No. 852 of 10937
# Batch No. 853 of 10937
# Batch No. 854 of 10937
# Batch No. 855 of 10937
# Batch No. 856 of 10937
# Batch No. 857 of 10937
# Batch No. 858 of 10937
# Batch No. 859 of 10937
# Batch No. 860 of 10937
# Batch No. 861 of 10937
# Batch No. 862 of 10937
# Batch No. 863 of 10937
# Batch No. 864 of 10937
# Batch No. 865 of 10937
# Batch No. 866 of 10937
# Batch No. 867 of 10937
# Batch No. 868 of 10937
# Batch No. 869 of 10937
# Batch No. 870 of 10937
# Batch No. 871 of 10937
# Batch No. 872 of 10937
# Batch No. 873 of 10937
# Batch No. 874 of 10937
# Batch No. 875 of 10937
# Batch No. 876 of 10937
# Batch No. 877 of 10937
# Batch No. 878 of 10937
# Batch No. 879 of 10937
# Batch No. 880 of 10937
# Batch No. 881 of 10937
# Batch No. 882 of 10937
# Batch No. 883 of 10937
# Batch No. 884 of 10937
# Batch No. 885 of 10937
# Batch No. 886 of 10937
# Batch No. 887 of 10937
# Batch No. 888 of 10937
# Batch No. 889 of 10937
# Batch No. 890 of 10937
# Batch No. 891 of 10937
# Batch No. 892 of 10937
# Batch No. 893 of 10937
# Batch No. 894 of 10937
# Batch No. 895 of 10937
# Batch No. 896 of 10937
# Batch No. 897 of 10937
# Batch No. 898 of 10937
# Batch No. 899 of 10937
# Batch No. 900 of 10937
# Batch No. 901 of 10937
# Batch No. 902 of 10937
# Batch No. 903 of 10937
# Batch No. 904 of 10937
# Batch No. 905 of 10937
# Batch No. 906 of 10937
# Batch No. 907 of 10937
# Batch No. 908 of 10937
# Batch No. 909 of 10937
# Batch No. 910 of 10937
# Batch No. 911 of 10937
# Batch No. 912 of 10937
# Batch No. 913 of 10937
# Batch No. 914 of 10937
# Batch No. 915 of 10937
# Batch No. 916 of 10937
# Batch No. 917 of 10937
# Batch No. 918 of 10937
# Batch No. 919 of 10937
# Batch No. 920 of 10937
# Batch No. 921 of 10937
# Batch No. 922 of 10937
# Batch No. 923 of 10937
# Batch No. 924 of 10937
# Batch No. 925 of 10937
# Batch No. 926 of 10937
# Batch No. 927 of 10937
# Batch No. 928 of 10937
# Batch No. 929 of 10937
# Batch No. 930 of 10937
# Batch No. 931 of 10937
# Batch No. 932 of 10937
# Batch No. 933 of 10937
# Batch No. 934 of 10937
# Batch No. 935 of 10937
# Batch No. 936 of 10937
# Batch No. 937 of 10937
# Batch No. 938 of 10937
# Batch No. 939 of 10937
# Batch No. 940 of 10937
# Batch No. 941 of 10937
# Batch No. 942 of 10937
# Batch No. 943 of 10937
# Batch No. 944 of 10937
# Batch No. 945 of 10937
# Batch No. 946 of 10937
# Batch No. 947 of 10937
# Batch No. 948 of 10937
# Batch No. 949 of 10937
# Batch No. 950 of 10937
# Batch No. 951 of 10937
# Batch No. 952 of 10937
# Batch No. 953 of 10937
# Batch No. 954 of 10937
# Batch No. 955 of 10937
# Batch No. 956 of 10937
# Batch No. 957 of 10937
# Batch No. 958 of 10937
# Batch No. 959 of 10937
# Batch No. 960 of 10937
# Batch No. 961 of 10937
# Batch No. 962 of 10937
# Batch No. 963 of 10937
# Batch No. 964 of 10937
# Batch No. 965 of 10937
# Batch No. 966 of 10937
# Batch No. 967 of 10937
# Batch No. 968 of 10937
# Batch No. 969 of 10937
# Batch No. 970 of 10937
# Batch No. 971 of 10937
# Batch No. 972 of 10937
# Batch No. 973 of 10937
# Batch No. 974 of 10937
# Batch No. 975 of 10937
# Batch No. 976 of 10937
# Batch No. 977 of 10937
# Batch No. 978 of 10937
# Batch No. 979 of 10937
# Batch No. 980 of 10937
# Batch No. 981 of 10937
# Batch No. 982 of 10937
# Batch No. 983 of 10937
# Batch No. 984 of 10937
# Batch No. 985 of 10937
# Batch No. 986 of 10937
# Batch No. 987 of 10937
# Batch No. 988 of 10937
# Batch No. 989 of 10937
# Batch No. 990 of 10937
# Batch No. 991 of 10937
# Batch No. 992 of 10937
# Batch No. 993 of 10937
# Batch No. 994 of 10937
# Batch No. 995 of 10937
# Batch No. 996 of 10937
# Batch No. 997 of 10937
# Batch No. 998 of 10937
# Batch No. 999 of 10937
# Batch No. 1000 of 10937
# Batch No. 1001 of 10937
# Batch No. 1002 of 10937
# Batch No. 1003 of 10937
# Batch No. 1004 of 10937
# Batch No. 1005 of 10937
# Batch No. 1006 of 10937
# Batch No. 1007 of 10937
# Batch No. 1008 of 10937
# Batch No. 1009 of 10937
# Batch No. 1010 of 10937
# Batch No. 1011 of 10937
# Batch No. 1012 of 10937
# Batch No. 1013 of 10937
# Batch No. 1014 of 10937
# Batch No. 1015 of 10937
# Batch No. 1016 of 10937
# Batch No. 1017 of 10937
# Batch No. 1018 of 10937
# Batch No. 1019 of 10937
# Batch No. 1020 of 10937
# Batch No. 1021 of 10937
# Batch No. 1022 of 10937
# Batch No. 1023 of 10937
# Batch No. 1024 of 10937
# Batch No. 1025 of 10937
# Batch No. 1026 of 10937
# Batch No. 1027 of 10937
# Batch No. 1028 of 10937
# Batch No. 1029 of 10937
# Batch No. 1030 of 10937
# Batch No. 1031 of 10937
# Batch No. 1032 of 10937
# Batch No. 1033 of 10937
# Batch No. 1034 of 10937
# Batch No. 1035 of 10937
# Batch No. 1036 of 10937
# Batch No. 1037 of 10937
# Batch No. 1038 of 10937
# Batch No. 1039 of 10937
# Batch No. 1040 of 10937
# Batch No. 1041 of 10937
# Batch No. 1042 of 10937
# Batch No. 1043 of 10937
# Batch No. 1044 of 10937
# Batch No. 1045 of 10937
# Batch No. 1046 of 10937
# Batch No. 1047 of 10937
# Batch No. 1048 of 10937
# Batch No. 1049 of 10937
# Batch No. 1050 of 10937
# Batch No. 1051 of 10937
# Batch No. 1052 of 10937
# Batch No. 1053 of 10937
# Batch No. 1054 of 10937
# Batch No. 1055 of 10937
# Batch No. 1056 of 10937
# Batch No. 1057 of 10937
# Batch No. 1058 of 10937
# Batch No. 1059 of 10937
# Batch No. 1060 of 10937
# Batch No. 1061 of 10937
# Batch No. 1062 of 10937
# Batch No. 1063 of 10937
# Batch No. 1064 of 10937
# Batch No. 1065 of 10937
# Batch No. 1066 of 10937
# Batch No. 1067 of 10937
# Batch No. 1068 of 10937
# Batch No. 1069 of 10937
# Batch No. 1070 of 10937
# Batch No. 1071 of 10937
# Batch No. 1072 of 10937
# Batch No. 1073 of 10937
# Batch No. 1074 of 10937
# Batch No. 1075 of 10937
# Batch No. 1076 of 10937
# Batch No. 1077 of 10937
# Batch No. 1078 of 10937
# Batch No. 1079 of 10937
# Batch No. 1080 of 10937
# Batch No. 1081 of 10937
# Batch No. 1082 of 10937
# Batch No. 1083 of 10937
# Batch No. 1084 of 10937
# Batch No. 1085 of 10937
# Batch No. 1086 of 10937
# Batch No. 1087 of 10937
# Batch No. 1088 of 10937
# Batch No. 1089 of 10937
# Batch No. 1090 of 10937
# Batch No. 1091 of 10937
# Batch No. 1092 of 10937
# Batch No. 1093 of 10937
# Batch No. 1094 of 10937
# Batch No. 1095 of 10937
# Batch No. 1096 of 10937
# Batch No. 1097 of 10937
# Batch No. 1098 of 10937
# Batch No. 1099 of 10937
# Batch No. 1100 of 10937
# Batch No. 1101 of 10937
# Batch No. 1102 of 10937
# Batch No. 1103 of 10937
# Batch No. 1104 of 10937
# Batch No. 1105 of 10937
# Batch No. 1106 of 10937
# Batch No. 1107 of 10937
# Batch No. 1108 of 10937
# Batch No. 1109 of 10937
# Batch No. 1110 of 10937
# Batch No. 1111 of 10937
# Batch No. 1112 of 10937
# Batch No. 1113 of 10937
# Batch No. 1114 of 10937
# Batch No. 1115 of 10937
# Batch No. 1116 of 10937
# Batch No. 1117 of 10937
# Batch No. 1118 of 10937
# Batch No. 1119 of 10937
# Batch No. 1120 of 10937
# Batch No. 1121 of 10937
# Batch No. 1122 of 10937
# Batch No. 1123 of 10937
# Batch No. 1124 of 10937
# Batch No. 1125 of 10937
# Batch No. 1126 of 10937
# Batch No. 1127 of 10937
# Batch No. 1128 of 10937
# Batch No. 1129 of 10937
# Batch No. 1130 of 10937
# Batch No. 1131 of 10937
# Batch No. 1132 of 10937
# Batch No. 1133 of 10937
# Batch No. 1134 of 10937
# Batch No. 1135 of 10937
# Batch No. 1136 of 10937
# Batch No. 1137 of 10937
# Batch No. 1138 of 10937
# Batch No. 1139 of 10937
# Batch No. 1140 of 10937
# Batch No. 1141 of 10937
# Batch No. 1142 of 10937
# Batch No. 1143 of 10937
# Batch No. 1144 of 10937
# Batch No. 1145 of 10937
# Batch No. 1146 of 10937
# Batch No. 1147 of 10937
# Batch No. 1148 of 10937
# Batch No. 1149 of 10937
# Batch No. 1150 of 10937
# Batch No. 1151 of 10937
# Batch No. 1152 of 10937
# Batch No. 1153 of 10937
# Batch No. 1154 of 10937
# Batch No. 1155 of 10937
# Batch No. 1156 of 10937
# Batch No. 1157 of 10937
# Batch No. 1158 of 10937
# Batch No. 1159 of 10937
# Batch No. 1160 of 10937
# Batch No. 1161 of 10937
# Batch No. 1162 of 10937
# Batch No. 1163 of 10937
# Batch No. 1164 of 10937
# Batch No. 1165 of 10937
# Batch No. 1166 of 10937
# Batch No. 1167 of 10937
# Batch No. 1168 of 10937
# Batch No. 1169 of 10937
# Batch No. 1170 of 10937
# Batch No. 1171 of 10937
# Batch No. 1172 of 10937
# Batch No. 1173 of 10937
# Batch No. 1174 of 10937
# Batch No. 1175 of 10937
# Batch No. 1176 of 10937
# Batch No. 1177 of 10937
# Batch No. 1178 of 10937
# Batch No. 1179 of 10937
# Batch No. 1180 of 10937
# Batch No. 1181 of 10937
# Batch No. 1182 of 10937
# Batch No. 1183 of 10937
# Batch No. 1184 of 10937
# Batch No. 1185 of 10937
# Batch No. 1186 of 10937
# Batch No. 1187 of 10937
# Batch No. 1188 of 10937
# Batch No. 1189 of 10937
# Batch No. 1190 of 10937
# Batch No. 1191 of 10937
# Batch No. 1192 of 10937
# Batch No. 1193 of 10937
# Batch No. 1194 of 10937
# Batch No. 1195 of 10937
# Batch No. 1196 of 10937
# Batch No. 1197 of 10937
# Batch No. 1198 of 10937
# Batch No. 1199 of 10937
# Batch No. 1200 of 10937
# Batch No. 1201 of 10937
# Batch No. 1202 of 10937
# Batch No. 1203 of 10937
# Batch No. 1204 of 10937
# Batch No. 1205 of 10937
# Batch No. 1206 of 10937
# Batch No. 1207 of 10937
# Batch No. 1208 of 10937
# Batch No. 1209 of 10937
# Batch No. 1210 of 10937
# Batch No. 1211 of 10937
# Batch No. 1212 of 10937
# Batch No. 1213 of 10937
# Batch No. 1214 of 10937
# Batch No. 1215 of 10937
# Batch No. 1216 of 10937
# Batch No. 1217 of 10937
# Batch No. 1218 of 10937
# Batch No. 1219 of 10937
# Batch No. 1220 of 10937
# Batch No. 1221 of 10937
# Batch No. 1222 of 10937
# Batch No. 1223 of 10937
# Batch No. 1224 of 10937
# Batch No. 1225 of 10937
# Batch No. 1226 of 10937
# Batch No. 1227 of 10937
# Batch No. 1228 of 10937
# Batch No. 1229 of 10937
# Batch No. 1230 of 10937
# Batch No. 1231 of 10937
# Batch No. 1232 of 10937
# Batch No. 1233 of 10937
# Batch No. 1234 of 10937
# Batch No. 1235 of 10937
# Batch No. 1236 of 10937
# Batch No. 1237 of 10937
# Batch No. 1238 of 10937
# Batch No. 1239 of 10937
# Batch No. 1240 of 10937
# Batch No. 1241 of 10937
# Batch No. 1242 of 10937
# Batch No. 1243 of 10937
# Batch No. 1244 of 10937
# Batch No. 1245 of 10937
# Batch No. 1246 of 10937
# Batch No. 1247 of 10937
# Batch No. 1248 of 10937
# Batch No. 1249 of 10937
# Batch No. 1250 of 10937
# Batch No. 1251 of 10937
# Batch No. 1252 of 10937
# Batch No. 1253 of 10937
# Batch No. 1254 of 10937
# Batch No. 1255 of 10937
# Batch No. 1256 of 10937
# Batch No. 1257 of 10937
# Batch No. 1258 of 10937
# Batch No. 1259 of 10937
# Batch No. 1260 of 10937
# Batch No. 1261 of 10937
# Batch No. 1262 of 10937
# Batch No. 1263 of 10937
# Batch No. 1264 of 10937
# Batch No. 1265 of 10937
# Batch No. 1266 of 10937
# Batch No. 1267 of 10937
# Batch No. 1268 of 10937
# Batch No. 1269 of 10937
# Batch No. 1270 of 10937
# Batch No. 1271 of 10937
# Batch No. 1272 of 10937
# Batch No. 1273 of 10937
# Batch No. 1274 of 10937
# Batch No. 1275 of 10937
# Batch No. 1276 of 10937
# Batch No. 1277 of 10937
# Batch No. 1278 of 10937
# Batch No. 1279 of 10937
# Batch No. 1280 of 10937
# Batch No. 1281 of 10937
# Batch No. 1282 of 10937
# Batch No. 1283 of 10937
# Batch No. 1284 of 10937
# Batch No. 1285 of 10937
# Batch No. 1286 of 10937
# Batch No. 1287 of 10937
# Batch No. 1288 of 10937
# Batch No. 1289 of 10937
# Batch No. 1290 of 10937
# Batch No. 1291 of 10937
# Batch No. 1292 of 10937
# Batch No. 1293 of 10937
# Batch No. 1294 of 10937
# Batch No. 1295 of 10937
# Batch No. 1296 of 10937
# Batch No. 1297 of 10937
# Batch No. 1298 of 10937
# Batch No. 1299 of 10937
# Batch No. 1300 of 10937
# Batch No. 1301 of 10937
# Batch No. 1302 of 10937
# Batch No. 1303 of 10937
# Batch No. 1304 of 10937
# Batch No. 1305 of 10937
# Batch No. 1306 of 10937
# Batch No. 1307 of 10937
# Batch No. 1308 of 10937
# Batch No. 1309 of 10937
# Batch No. 1310 of 10937
# Batch No. 1311 of 10937
# Batch No. 1312 of 10937
# Batch No. 1313 of 10937
# Batch No. 1314 of 10937
# Batch No. 1315 of 10937
# Batch No. 1316 of 10937
# Batch No. 1317 of 10937
# Batch No. 1318 of 10937
# Batch No. 1319 of 10937
# Batch No. 1320 of 10937
# Batch No. 1321 of 10937
# Batch No. 1322 of 10937
# Batch No. 1323 of 10937
# Batch No. 1324 of 10937
# Batch No. 1325 of 10937
# Batch No. 1326 of 10937
# Batch No. 1327 of 10937
# Batch No. 1328 of 10937
# Batch No. 1329 of 10937
# Batch No. 1330 of 10937
# Batch No. 1331 of 10937
# Batch No. 1332 of 10937
# Batch No. 1333 of 10937
# Batch No. 1334 of 10937
# Batch No. 1335 of 10937
# Batch No. 1336 of 10937
# Batch No. 1337 of 10937
# Batch No. 1338 of 10937
# Batch No. 1339 of 10937
# Batch No. 1340 of 10937
# Batch No. 1341 of 10937
# Batch No. 1342 of 10937
# Batch No. 1343 of 10937
# Batch No. 1344 of 10937
# Batch No. 1345 of 10937
# Batch No. 1346 of 10937
# Batch No. 1347 of 10937
# Batch No. 1348 of 10937
# Batch No. 1349 of 10937
# Batch No. 1350 of 10937
# Batch No. 1351 of 10937
# Batch No. 1352 of 10937
# Batch No. 1353 of 10937
# Batch No. 1354 of 10937
# Batch No. 1355 of 10937
# Batch No. 1356 of 10937
# Batch No. 1357 of 10937
# Batch No. 1358 of 10937
# Batch No. 1359 of 10937
# Batch No. 1360 of 10937
# Batch No. 1361 of 10937
# Batch No. 1362 of 10937
# Batch No. 1363 of 10937
# Batch No. 1364 of 10937
# Batch No. 1365 of 10937
# Batch No. 1366 of 10937
# Batch No. 1367 of 10937
# Batch No. 1368 of 10937
# Batch No. 1369 of 10937
# Batch No. 1370 of 10937
# Batch No. 1371 of 10937
# Batch No. 1372 of 10937
# Batch No. 1373 of 10937
# Batch No. 1374 of 10937
# Batch No. 1375 of 10937
# Batch No. 1376 of 10937
# Batch No. 1377 of 10937
# Batch No. 1378 of 10937
# Batch No. 1379 of 10937
# Batch No. 1380 of 10937
# Batch No. 1381 of 10937
# Batch No. 1382 of 10937
# Batch No. 1383 of 10937
# Batch No. 1384 of 10937
# Batch No. 1385 of 10937
# Batch No. 1386 of 10937
# Batch No. 1387 of 10937
# Batch No. 1388 of 10937
# Batch No. 1389 of 10937
# Batch No. 1390 of 10937
# Batch No. 1391 of 10937
# Batch No. 1392 of 10937
# Batch No. 1393 of 10937
# Batch No. 1394 of 10937
# Batch No. 1395 of 10937
# Batch No. 1396 of 10937
# Batch No. 1397 of 10937
# Batch No. 1398 of 10937
# Batch No. 1399 of 10937
# Batch No. 1400 of 10937
# Batch No. 1401 of 10937
# Batch No. 1402 of 10937
# Batch No. 1403 of 10937
# Batch No. 1404 of 10937
# Batch No. 1405 of 10937
# Batch No. 1406 of 10937
# Batch No. 1407 of 10937
# Batch No. 1408 of 10937
# Batch No. 1409 of 10937
# Batch No. 1410 of 10937
# Batch No. 1411 of 10937
# Batch No. 1412 of 10937
# Batch No. 1413 of 10937
# Batch No. 1414 of 10937
# Batch No. 1415 of 10937
# Batch No. 1416 of 10937
# Batch No. 1417 of 10937
# Batch No. 1418 of 10937
# Batch No. 1419 of 10937
# Batch No. 1420 of 10937
# Batch No. 1421 of 10937
# Batch No. 1422 of 10937
# Batch No. 1423 of 10937
# Batch No. 1424 of 10937
# Batch No. 1425 of 10937
# Batch No. 1426 of 10937
# Batch No. 1427 of 10937
# Batch No. 1428 of 10937
# Batch No. 1429 of 10937
# Batch No. 1430 of 10937
# Batch No. 1431 of 10937
# Batch No. 1432 of 10937
# Batch No. 1433 of 10937
# Batch No. 1434 of 10937
# Batch No. 1435 of 10937
# Batch No. 1436 of 10937
# Batch No. 1437 of 10937
# Batch No. 1438 of 10937
# Batch No. 1439 of 10937
# Batch No. 1440 of 10937
# Batch No. 1441 of 10937
# Batch No. 1442 of 10937
# Batch No. 1443 of 10937
# Batch No. 1444 of 10937
# Batch No. 1445 of 10937
# Batch No. 1446 of 10937
# Batch No. 1447 of 10937
# Batch No. 1448 of 10937
# Batch No. 1449 of 10937
# Batch No. 1450 of 10937
# Batch No. 1451 of 10937
# Batch No. 1452 of 10937
# Batch No. 1453 of 10937
# Batch No. 1454 of 10937
# Batch No. 1455 of 10937
# Batch No. 1456 of 10937
# Batch No. 1457 of 10937
# Batch No. 1458 of 10937
# Batch No. 1459 of 10937
# Batch No. 1460 of 10937
# Batch No. 1461 of 10937
# Batch No. 1462 of 10937
# Batch No. 1463 of 10937
# Batch No. 1464 of 10937
# Batch No. 1465 of 10937
# Batch No. 1466 of 10937
# Batch No. 1467 of 10937
# Batch No. 1468 of 10937
# Batch No. 1469 of 10937
# Batch No. 1470 of 10937
# Batch No. 1471 of 10937
# Batch No. 1472 of 10937
# Batch No. 1473 of 10937
# Batch No. 1474 of 10937
# Batch No. 1475 of 10937
# Batch No. 1476 of 10937
# Batch No. 1477 of 10937
# Batch No. 1478 of 10937
# Batch No. 1479 of 10937
# Batch No. 1480 of 10937
# Batch No. 1481 of 10937
# Batch No. 1482 of 10937
# Batch No. 1483 of 10937
# Batch No. 1484 of 10937
# Batch No. 1485 of 10937
# Batch No. 1486 of 10937
# Batch No. 1487 of 10937
# Batch No. 1488 of 10937
# Batch No. 1489 of 10937
# Batch No. 1490 of 10937
# Batch No. 1491 of 10937
# Batch No. 1492 of 10937
# Batch No. 1493 of 10937
# Batch No. 1494 of 10937
# Batch No. 1495 of 10937
# Batch No. 1496 of 10937
# Batch No. 1497 of 10937
# Batch No. 1498 of 10937
# Batch No. 1499 of 10937
# Batch No. 1500 of 10937
# Batch No. 1501 of 10937
# Batch No. 1502 of 10937
# Batch No. 1503 of 10937
# Batch No. 1504 of 10937
# Batch No. 1505 of 10937
# Batch No. 1506 of 10937
# Batch No. 1507 of 10937
# Batch No. 1508 of 10937
# Batch No. 1509 of 10937
# Batch No. 1510 of 10937
# Batch No. 1511 of 10937
# Batch No. 1512 of 10937
# Batch No. 1513 of 10937
# Batch No. 1514 of 10937
# Batch No. 1515 of 10937
# Batch No. 1516 of 10937
# Batch No. 1517 of 10937
# Batch No. 1518 of 10937
# Batch No. 1519 of 10937
# Batch No. 1520 of 10937
# Batch No. 1521 of 10937
# Batch No. 1522 of 10937
# Batch No. 1523 of 10937
# Batch No. 1524 of 10937
# Batch No. 1525 of 10937
# Batch No. 1526 of 10937
# Batch No. 1527 of 10937
# Batch No. 1528 of 10937
# Batch No. 1529 of 10937
# Batch No. 1530 of 10937
# Batch No. 1531 of 10937
# Batch No. 1532 of 10937
# Batch No. 1533 of 10937
# Batch No. 1534 of 10937
# Batch No. 1535 of 10937
# Batch No. 1536 of 10937
# Batch No. 1537 of 10937
# Batch No. 1538 of 10937
# Batch No. 1539 of 10937
# Batch No. 1540 of 10937
# Batch No. 1541 of 10937
# Batch No. 1542 of 10937
# Batch No. 1543 of 10937
# Batch No. 1544 of 10937
# Batch No. 1545 of 10937
# Batch No. 1546 of 10937
# Batch No. 1547 of 10937
# Batch No. 1548 of 10937
# Batch No. 1549 of 10937
# Batch No. 1550 of 10937
# Batch No. 1551 of 10937
# Batch No. 1552 of 10937
# Batch No. 1553 of 10937
# Batch No. 1554 of 10937
# Batch No. 1555 of 10937
# Batch No. 1556 of 10937
# Batch No. 1557 of 10937
# Batch No. 1558 of 10937
# Batch No. 1559 of 10937
# Batch No. 1560 of 10937
# Batch No. 1561 of 10937
# Batch No. 1562 of 10937
# Batch No. 1563 of 10937
# Batch No. 1564 of 10937
# Batch No. 1565 of 10937
# Batch No. 1566 of 10937
# Batch No. 1567 of 10937
# Batch No. 1568 of 10937
# Batch No. 1569 of 10937
# Batch No. 1570 of 10937
# Batch No. 1571 of 10937
# Batch No. 1572 of 10937
# Batch No. 1573 of 10937
# Batch No. 1574 of 10937
# Batch No. 1575 of 10937
# Batch No. 1576 of 10937
# Batch No. 1577 of 10937
# Batch No. 1578 of 10937
# Batch No. 1579 of 10937
# Batch No. 1580 of 10937
# Batch No. 1581 of 10937
# Batch No. 1582 of 10937
# Batch No. 1583 of 10937
# Batch No. 1584 of 10937
# Batch No. 1585 of 10937
# Batch No. 1586 of 10937
# Batch No. 1587 of 10937
# Batch No. 1588 of 10937
# Batch No. 1589 of 10937
# Batch No. 1590 of 10937
# Batch No. 1591 of 10937
# Batch No. 1592 of 10937
# Batch No. 1593 of 10937
# Batch No. 1594 of 10937
# Batch No. 1595 of 10937
# Batch No. 1596 of 10937
# Batch No. 1597 of 10937
# Batch No. 1598 of 10937
# Batch No. 1599 of 10937
# Batch No. 1600 of 10937
# Batch No. 1601 of 10937
# Batch No. 1602 of 10937
# Batch No. 1603 of 10937
# Batch No. 1604 of 10937
# Batch No. 1605 of 10937
# Batch No. 1606 of 10937
# Batch No. 1607 of 10937
# Batch No. 1608 of 10937
# Batch No. 1609 of 10937
# Batch No. 1610 of 10937
# Batch No. 1611 of 10937
# Batch No. 1612 of 10937
# Batch No. 1613 of 10937
# Batch No. 1614 of 10937
# Batch No. 1615 of 10937
# Batch No. 1616 of 10937
# Batch No. 1617 of 10937
# Batch No. 1618 of 10937
# Batch No. 1619 of 10937
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-e952b212efbe> in <module>()
#      12                      summary_length: summaries_lengths,
#      13                      text_length: texts_lengths,
# ---> 14                      keep_prob: keep_probability})
#      15     print("Batch No. %d of %d"%(batch_i+1,int(len(train_summaries)/batch_size)))
#      16     train_logits.extend(ilog.tolist())
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
print("Average Rouge Socres :", rouge.get_scores(all_pred, all_summ, avg = True))
# Out:
# Average Rouge Socres : {'rouge-1': {'f': 0.12376427897287923, 'p': 0.13526231720904244, 'r': 0.12198089229377379}, 'rouge-2': {'f': 0.01626121191644408, 'p': 0.015450675832679069, 'r': 0.018597545720308317}, 'rouge-l': {'f': 0.11026323894579852, 'p': 0.12765404174533782, 'r': 0.11488721068993046}}

# %% [markdown]
# ##Training Result Cases

# %%
checkpoint = "final_best_model_multigraph.ckpt" 
with tf.Session(graph=train_graph) as sess:
  saver = tf.train.Saver()
  saver.restore(sess,os.path.join(ckpt_path,type_val,checkpoint))
  train_logits = []
  for batch_i, (summaries_batch, texts_batch, summaries_lengths, texts_lengths) in enumerate(
          get_batches(train_summaries[:val], train_texts[:val], params['batch_size'])):
    ilog = sess.run( ob.inference_logits,
          {ob.encoder_inputs: texts_batch,
           ob.decoder_targets: summaries_batch,
           ob.learning_rate: learning_rate,
           ob.decoder_lengths: summaries_lengths,
           ob.encoder_lengths: texts_lengths})
    print("Batch No. %d of %d"%(batch_i+1,int(len(train_summaries[:val])/params['batch_size'])))
    train_logits.extend(ilog.tolist())
  rouge = Rouge()
  all_pred, all_summ, all_texts = [], [], []
  for i in range(len(train_logits)):
    pred = " ".join([int_to_vocab[train_logits[i][k]] if train_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(train_logits[i]))])
    true = " ".join([int_to_vocab[train_summaries[:val][i][k]] if train_logits[i][k] in int_to_vocab.keys() else '<UNK>' for k in range(len(train_summaries[:val][i]))])
    text = " ".join([int_to_vocab[train_texts[:val][i][k]] for k in range(len(train_texts[:val][i]))])
    r_values = rouge.get_scores(pred, true)
    if(r_values[0]['rouge-1']['f'] > train_limit):
      print("Text : ", text, "\n", "Actual Summary : ", true, "\n System Summary : ", pred, "\n", r_values, "\n")
# Out:
# INFO:tensorflow:Restoring parameters from gdrive/My Drive/Ab_Summarization/Our_Own_Code/Model_Check_Points/final_best_model.ckpt
# Batch No. 1 of 15
# Batch No. 2 of 15
# Batch No. 3 of 15
# Batch No. 4 of 15
# Batch No. 5 of 15
# Batch No. 6 of 15
# Batch No. 7 of 15
# Batch No. 8 of 15
# Batch No. 9 of 15
# Batch No. 10 of 15
# Batch No. 11 of 15
# Batch No. 12 of 15
# Batch No. 13 of 15
# Batch No. 14 of 15
# Batch No. 15 of 15
# Text :  taiwan shares closed down percent monday on wall street weakness and lacklustre interim earnings from electronics manufacturing giant hon hai dealers said <EOS>
#  Actual Summary :  taiwan shares close down percent
#  System Summary :  two shares close percent lower on weak jobs concerns jobs concerns
#  [{'rouge-1': {'f': 0.4285714239795918, 'p': 0.3333333333333333, 'r': 0.6}, 'rouge-2': {'f': 0.15384614958579892, 'p': 0.1111111111111111, 'r': 0.25}, 'rouge-l': {'f': 0.3723653395778134, 'p': 0.3333333333333333, 'r': 0.6}}]
#
# Text :  the united states will provide million dollars in aid to help storm ravaged haiti recover from deadly tropical storms white house spokeswoman dana perino said wednesday <EOS>
#  Actual Summary :  us to give million dollars in aid to storm hit haiti
#  System Summary :  at to haiti haiti in afghanistan haiti aid to haiti haiti
#  [{'rouge-1': {'f': 0.49999999531250006, 'p': 0.6666666666666666, 'r': 0.4}, 'rouge-2': {'f': 0.11111110617283973, 'p': 0.125, 'r': 0.1}, 'rouge-l': {'f': 0.4473684210526277, 'p': 0.6666666666666666, 'r': 0.4}}]
#
# Text :  un chief ban ki moon hailed the power sharing deal reached by the zimbabwean government and its opposition in harare thursday and voiced hope it would pave the way for durable peace and recovery <EOS>
#  Actual Summary :  un chief hails power sharing deal in zimbabwe
#  System Summary :  macedonia power sharing deal to power sharing power sharing deal to
#  [{'rouge-1': {'f': 0.4615384568047337, 'p': 0.6, 'r': 0.375}, 'rouge-2': {'f': 0.3076923027218935, 'p': 0.3333333333333333, 'r': 0.2857142857142857}, 'rouge-l': {'f': 0.4191522762951034, 'p': 0.6, 'r': 0.375}}]
#
# Text :  the gulf of mexico where hurricane ike churned thursday is a hub of the us petroleum industry where a quarter of us crude oil is produced and percent of refinery capacity is concentrated <EOS>
#  Actual Summary :  gulf of mexico hub of us oil industry
#  System Summary :  another oil leak of us oil leak in us data oil leak in
#  [{'rouge-1': {'f': 0.4285714235714286, 'p': 0.42857142857142855, 'r': 0.42857142857142855}, 'rouge-2': {'f': 0.24999999507812506, 'p': 0.2222222222222222, 'r': 0.2857142857142857}, 'rouge-l': {'f': 0.4285714285709285, 'p': 0.42857142857142855, 'r': 0.42857142857142855}}]
#
# Text :  oil and natural gas production in the gulf of mexico has been largely shut off as hurricane ike looms the us department of energy said thursday adding however that the storm was likely to spare most gulf energy installations <EOS>
#  Actual Summary :  oil gas production in gulf of mexico largely shut off as ike looms
#  System Summary :  sees oil gas leak in gulf gas leak in gulf gas leak gas
#  [{'rouge-1': {'f': 0.4210526272576177, 'p': 0.6666666666666666, 'r': 0.3076923076923077}, 'rouge-2': {'f': 0.2105263111357342, 'p': 0.2857142857142857, 'r': 0.16666666666666666}, 'rouge-l': {'f': 0.33982594280987166, 'p': 0.6666666666666666, 'r': 0.3076923076923077}}]
#
# Text :  a bomb blast and an attack on a combat post killed two nato soldiers in afghanistan one of them british the alliance s international security assistance force and british military said thursday <EOS>
#  Actual Summary :  two nato soldiers killed in afghanistan
#  System Summary :  afghan nato soldiers killed in afghanistan raid raid nato soldier nato
#  [{'rouge-1': {'f': 0.7142857093877552, 'p': 0.625, 'r': 0.8333333333333334}, 'rouge-2': {'f': 0.533333328888889, 'p': 0.4, 'r': 0.8}, 'rouge-l': {'f': 0.6868131868125028, 'p': 0.625, 'r': 0.8333333333333334}}]
#
# Text :  afghan president hamid karzai thursday welcomed a new us `` war on terror focus on pakistan s border areas as further deadly violence underscored rampant militancy seven years after the september attacks <EOS>
#  Actual Summary :  afghanistan welcomes war on terror shift on \ anniversary
#  System Summary :  macedonia afghan war on terror anniversary violence in afghanistan violence in
#  [{'rouge-1': {'f': 0.5882352891349482, 'p': 0.5555555555555556, 'r': 0.625}, 'rouge-2': {'f': 0.23529411266435996, 'p': 0.2222222222222222, 'r': 0.25}, 'rouge-l': {'f': 0.4673650282024591, 'p': 0.4444444444444444, 'r': 0.5}}]
#
# Text :  samak sundaravej was poised thursday to return as thailand s premier just two days after a court removed him from the post angering protesters who vowed to press their campaign to oust him <EOS>
#  Actual Summary :  samak poised to return as thai pm two days after dismissal
#  System Summary :  reject thai pm s pm to return to return home after thai
#  [{'rouge-1': {'f': 0.5263157845983379, 'p': 0.625, 'r': 0.45454545454545453}, 'rouge-2': {'f': 0.19999999500000015, 'p': 0.2, 'r': 0.2}, 'rouge-l': {'f': 0.3011394465543743, 'p': 0.375, 'r': 0.2727272727272727}}]
#
# Text :  malaysian share prices ended percent lower thursday as investors sold off plantation and finance stocks amid a region wide slump dealers said <EOS>
#  Actual Summary :  malaysian shares close down percent
#  System Summary :  new new zealand shares close percent lower on us data data data
#  [{'rouge-1': {'f': 0.4285714239795918, 'p': 0.3333333333333333, 'r': 0.6}, 'rouge-2': {'f': 0.14285713877551035, 'p': 0.1, 'r': 0.25}, 'rouge-l': {'f': 0.3723653395778134, 'p': 0.3333333333333333, 'r': 0.6}}]
#
# Text :  a british solder has been killed in an explosion in southern afghanistan the ministry of defense in london said thursday bringing the total british toll in the afghan conflict to <EOS>
#  Actual Summary :  british soldier killed in afghanistan
#  System Summary :  top in afghanistan in afghanistan in afghanistan in afghanistan in afghanistan in
#  [{'rouge-1': {'f': 0.49999999531250006, 'p': 0.6666666666666666, 'r': 0.4}, 'rouge-2': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-l': {'f': 0.4473684210526277, 'p': 0.6666666666666666, 'r': 0.4}}]
#
# Text :  a suicide car bomb blew up near a convoy of private security guards in afghanistan s southern city of kandahar thursday killing two afghan civilian passers by a governor s spokesman said <EOS>
#  Actual Summary :  suicide attack in afghanistan two civilians killed
#  System Summary :  two afghan suicide attack kills killed in afghanistan afghan blast in afghanistan
#  [{'rouge-1': {'f': 0.7499999950781251, 'p': 0.6666666666666666, 'r': 0.8571428571428571}, 'rouge-2': {'f': 0.24999999531250006, 'p': 0.2, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.4850746268649977, 'p': 0.4444444444444444, 'r': 0.5714285714285714}}]
#
# Text :  hong kong share prices closed down percent on thursday marking an month low as investors dumped shares in chinese firms amid deepening fears of a global economic slowdown dealers said <EOS>
#  Actual Summary :  hong kong shares close down percent
#  System Summary :  wo shares close percent lower on markets fears fears fears fears
#  [{'rouge-1': {'f': 0.4285714236734694, 'p': 0.375, 'r': 0.5}, 'rouge-2': {'f': 0.1538461491124262, 'p': 0.125, 'r': 0.2}, 'rouge-l': {'f': 0.4120879120872282, 'p': 0.375, 'r': 0.5}}]
#
# Text :  indonesian shares closed percent lower thursday hurt by a weaker rupiah and further selling in commodity related stocks dealers said <EOS>
#  Actual Summary :  indonesian shares close down percent
#  System Summary :  austrian shares close percent lower in morning trade up percent in
#  [{'rouge-1': {'f': 0.4285714239795918, 'p': 0.3333333333333333, 'r': 0.6}, 'rouge-2': {'f': 0.14285713877551035, 'p': 0.1, 'r': 0.25}, 'rouge-l': {'f': 0.3723653395778134, 'p': 0.3333333333333333, 'r': 0.6}}]
#
# Text :  hong kong gold prices closed lower on thursday at us dollars an ounce down from wednesday s close of dollars <EOS>
#  Actual Summary :  hong kong gold closes lower
#  System Summary :  sees million dollars in hong kong gold gold gold gold gold
#  [{'rouge-1': {'f': 0.499999995138889, 'p': 0.42857142857142855, 'r': 0.6}, 'rouge-2': {'f': 0.36363635900826446, 'p': 0.2857142857142857, 'r': 0.5}, 'rouge-l': {'f': 0.47435897435828306, 'p': 0.42857142857142855, 'r': 0.6}}]
#
# Text :  south korean shares closed percent lower thursday weighed down by program selling due to the simultaneous expiry of options and futures dealers said <EOS>
#  Actual Summary :  skorean shares close percent lower
#  System Summary :  new shares close percent lower on weak fears fears in asian
#  [{'rouge-1': {'f': 0.533333328888889, 'p': 0.4, 'r': 0.8}, 'rouge-2': {'f': 0.4285714244897959, 'p': 0.3, 'r': 0.75}, 'rouge-l': {'f': 0.44444444444385184, 'p': 0.4, 'r': 0.8}}]
#
# Text :  european stock markets fell slightly at the start of trading on thursday with london s ftse index of leading shares down percent at points <EOS>
#  Actual Summary :  european stocks dip at open london down percent
#  System Summary :  new european markets fall at open london down percent at open
#  [{'rouge-1': {'f': 0.7058823479584776, 'p': 0.6666666666666666, 'r': 0.75}, 'rouge-2': {'f': 0.4999999950781251, 'p': 0.4444444444444444, 'r': 0.5714285714285714}, 'rouge-l': {'f': 0.70104754230399, 'p': 0.6666666666666666, 'r': 0.75}}]
#
# Text :  at least seven people were killed and injured in the powerful earthquake that struck southern iran on wednesday the mehr news agency reported on thursday <EOS>
#  Actual Summary :  seven dead in iran quake
#  System Summary :  iran quake kills in turkey quake hit iran quake quake quake
#  [{'rouge-1': {'f': 0.5454545404958678, 'p': 0.5, 'r': 0.6}, 'rouge-2': {'f': 0.16666666222222234, 'p': 0.125, 'r': 0.25}, 'rouge-l': {'f': 0.5366568914949571, 'p': 0.5, 'r': 0.6}}]
#
# Text :  pakistan and the united states were drawn into a dispute thursday over the right military strategy to hunt down al qaeda seven years after the september attacks stunned the world <EOS>
#  Actual Summary :  pakistan us clash over hunt for al qaeda
#  System Summary :  iran for action with terror terror plot over al qaeda threat in
#  [{'rouge-1': {'f': 0.42105262670360116, 'p': 0.36363636363636365, 'r': 0.5}, 'rouge-2': {'f': 0.11111110635802489, 'p': 0.09090909090909091, 'r': 0.14285714285714285}, 'rouge-l': {'f': 0.3011394465538413, 'p': 0.2727272727272727, 'r': 0.375}}]
#
# Text :  world oil prices rose in asian trade thursday as hurricane ike headed towards key energy facilities on the southern us coast dealers said <EOS>
#  Actual Summary :  oil prices up in asia on hurricane fears
#  System Summary :  new oil prices fall in asian trade in asian trade on us
#  [{'rouge-1': {'f': 0.4705882303114187, 'p': 0.4444444444444444, 'r': 0.5}, 'rouge-2': {'f': 0.12499999507812519, 'p': 0.1111111111111111, 'r': 0.14285714285714285}, 'rouge-l': {'f': 0.4673650282024591, 'p': 0.4444444444444444, 'r': 0.5}}]
#
# Text :  hong kong share prices opened percent down on thursday marking a fresh year to date low after falls on china bourses dealers said <EOS>
#  Actual Summary :  hong kong shares open percent down
#  System Summary :  mystery hong kong shares end morning percent lower on china hong kong
#  [{'rouge-1': {'f': 0.49999999531250006, 'p': 0.4, 'r': 0.6666666666666666}, 'rouge-2': {'f': 0.2666666622222223, 'p': 0.2, 'r': 0.4}, 'rouge-l': {'f': 0.44736842105196295, 'p': 0.4, 'r': 0.6666666666666666}}]
#
# Text :  the dollar stumbled friday on an unexpected fall in us retail sales in anxious trading reflecting market uncertainty surrounding the fate of ailing us investment giant lehman brothers <EOS>
#  Actual Summary :  dollar wilts on weak us retail sales shift in fed outlook
#  System Summary :  reject for record highs in may sales on weak us data data
#  [{'rouge-1': {'f': 0.45454544954545456, 'p': 0.45454545454545453, 'r': 0.45454545454545453}, 'rouge-2': {'f': 0.1904761854875285, 'p': 0.18181818181818182, 'r': 0.2}, 'rouge-l': {'f': 0.2727272727267727, 'p': 0.2727272727272727, 'r': 0.2727272727272727}}]
#
# Text :  three lawmakers cautioned the us congress on friday against rushing through with a vote on a landmark nuclear pact with india that president george w bush wants approved before he leaves office in january <EOS>
#  Actual Summary :  us lawmakers caution against rushing vote on indian nuclear deal
#  System Summary :  his obama on us nuclear issue on wednesday vote on nuclear vote
#  [{'rouge-1': {'f': 0.4444444395061729, 'p': 0.5, 'r': 0.4}, 'rouge-2': {'f': 0.09999999505000023, 'p': 0.09090909090909091, 'r': 0.1111111111111111}, 'rouge-l': {'f': 0.43386243386217854, 'p': 0.5, 'r': 0.4}}]
#
# Text :  the dollar wilted against the euro friday on an unexpected fall in us retail sales in anxious trading reflecting market uncertainty surrounding the fate of ailing us investment giant lehman brothers <EOS>
#  Actual Summary :  dollar wilts on unexpected fall in us retail sales
#  System Summary :  swiss for tuesday us jobs data sales in us us sales fall
#  [{'rouge-1': {'f': 0.44444443944444445, 'p': 0.4444444444444444, 'r': 0.4444444444444444}, 'rouge-2': {'f': 0.1052631530193908, 'p': 0.09090909090909091, 'r': 0.125}, 'rouge-l': {'f': 0.3333333333328333, 'p': 0.3333333333333333, 'r': 0.3333333333333333}}]
#
# Text :  us retail sales fell percent in august as a government fiscal stimulus faded with strong automobile sales helping offset a steeper decline the commerce department said friday <EOS>
#  Actual Summary :  us august retail sales in surprise slump
#  System Summary :  remains sales in may sales us sales in may sales up percent
#  [{'rouge-1': {'f': 0.4285714235714286, 'p': 0.42857142857142855, 'r': 0.42857142857142855}, 'rouge-2': {'f': 0.14285713795918387, 'p': 0.125, 'r': 0.16666666666666666}, 'rouge-l': {'f': 0.4285714285709285, 'p': 0.42857142857142855, 'r': 0.42857142857142855}}]
#
# Text :  deutsche post said friday it has sold a percent stake in its postbank unit to deutsche bank for billion euros lrb billion dollars rrb or euros per share in cash <EOS>
#  Actual Summary :  deutsche bank buys postbank stake for billion euros
#  System Summary :  serbia stake in bank sale for billion euros for bln euros
#  [{'rouge-1': {'f': 0.5882352891349482, 'p': 0.5555555555555556, 'r': 0.625}, 'rouge-2': {'f': 0.23529411280276827, 'p': 0.2, 'r': 0.2857142857142857}, 'rouge-l': {'f': 0.4673650282024591, 'p': 0.4444444444444444, 'r': 0.5}}]
#
# Text :  zimbabweans on friday awaited details of a power sharing deal to end a political crisis after tortuous talks centred on how much authority veteran leader robert mugabe would cede to the opposition <EOS>
#  Actual Summary :  zimbabwe rivals seal power sharing deal to end crisis
#  System Summary :  macedonia power sharing to end political crisis crisis crisis crisis talks
#  [{'rouge-1': {'f': 0.5882352891349482, 'p': 0.625, 'r': 0.5555555555555556}, 'rouge-2': {'f': 0.24999999500000009, 'p': 0.25, 'r': 0.25}, 'rouge-l': {'f': 0.5842062852534542, 'p': 0.625, 'r': 0.5555555555555556}}]
#
# Text :  hong kong share prices closed down percent on friday as weakness in china banks has offset earlier gains in property developers and energy firms dealers said <EOS>
#  Actual Summary :  hong kong shares close down percent
#  System Summary :  reject shares close percent lower on china fears fears fears fears
#  [{'rouge-1': {'f': 0.4285714236734694, 'p': 0.375, 'r': 0.5}, 'rouge-2': {'f': 0.1538461491124262, 'p': 0.125, 'r': 0.2}, 'rouge-l': {'f': 0.4120879120872282, 'p': 0.375, 'r': 0.5}}]
#
# Text :  australian officials friday charged three men over the death of a woman from a date rape drug overdose on a holiday cruise including one who had sex with her hours before she died <EOS>
#  Actual Summary :  three australians charged over cruise ship death
#  System Summary :  iran charged over death penalty case case case case case case
#  [{'rouge-1': {'f': 0.4615384565680473, 'p': 0.5, 'r': 0.42857142857142855}, 'rouge-2': {'f': 0.16666666166666683, 'p': 0.16666666666666666, 'r': 0.16666666666666666}, 'rouge-l': {'f': 0.45617173524117033, 'p': 0.5, 'r': 0.42857142857142855}}]
#
# Text :  chinese authorities announced a nationwide probe friday into a milk powder suspected of killing one baby and sickening dozens of others in the latest safety scandal to rock china s food industry <EOS>
#  Actual Summary :  china launches probe into milk powder after baby dies
#  System Summary :  iran probe into probe into china probe into china probe into
#  [{'rouge-1': {'f': 0.4615384572781066, 'p': 0.75, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.1538461491124262, 'p': 0.2, 'r': 0.125}, 'rouge-l': {'f': 0.3669609079446111, 'p': 0.75, 'r': 0.3333333333333333}}]
#
# Text :  philippine share prices closed percent lower on friday amid renewed apprehension about inflation and the local currency as well as credit problems in the united states dealers said <EOS>
#  Actual Summary :  philippine shares close percent lower
#  System Summary :  serbia shares close percent lower on weak us jobs data data fears
#  [{'rouge-1': {'f': 0.49999999570312514, 'p': 0.36363636363636365, 'r': 0.8}, 'rouge-2': {'f': 0.3999999960888889, 'p': 0.2727272727272727, 'r': 0.75}, 'rouge-l': {'f': 0.40109890109835716, 'p': 0.36363636363636365, 'r': 0.8}}]
#
# Text :  the us congress said thursday it would examine a landmark civilian nuclear agreement with india sent for approval by the white house as leaders of the two countries prepared to meet this month <EOS>
#  Actual Summary :  us congress vows to examine nuclear deal with india
#  System Summary :  sees nuclear deal with india nuclear talks with india nuclear deal with
#  [{'rouge-1': {'f': 0.5333333285333334, 'p': 0.6666666666666666, 'r': 0.4444444444444444}, 'rouge-2': {'f': 0.3999999950222222, 'p': 0.42857142857142855, 'r': 0.375}, 'rouge-l': {'f': 0.4952380952380168, 'p': 0.6666666666666666, 'r': 0.4444444444444444}}]
#
# Text :  barack obama s campaign announced sunday a record fundraising haul of million dollars in august amassing a big advantage over john mccain in the closing stretch of the white house race <EOS>
#  Actual Summary :  obama raises record million dollars in august
#  System Summary :  obama for million dollars in the cold of the top in
#  [{'rouge-1': {'f': 0.4999999950781251, 'p': 0.4444444444444444, 'r': 0.5714285714285714}, 'rouge-2': {'f': 0.24999999531250006, 'p': 0.2, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.4850746268649977, 'p': 0.4444444444444444, 'r': 0.5714285714285714}}]
#
# Text :  a bomb blast sunday in central afghanistan killed six children and wounded some of them critically a local official said <EOS>
#  Actual Summary :  bomb blast kills six children in afghanistan
#  System Summary :  obama earthquake kills two in afghanistan in afghanistan in afghanistan in afghanistan
#  [{'rouge-1': {'f': 0.4615384565680473, 'p': 0.5, 'r': 0.42857142857142855}, 'rouge-2': {'f': 0.16666666166666683, 'p': 0.16666666666666666, 'r': 0.16666666666666666}, 'rouge-l': {'f': 0.45617173524117033, 'p': 0.5, 'r': 0.42857142857142855}}]
#
# Text :  israel expressed outrage on sunday after a mob of jewish settlers rampaged through a palestinian village in the west bank to avenge the stabbing of a nine year old boy in a nearby settlement <EOS>
#  Actual Summary :  israel outraged after settler rampage in west bank
#  System Summary :  macedonia dead in west bank west bank raid in west bank west
#  [{'rouge-1': {'f': 0.4285714236734694, 'p': 0.5, 'r': 0.375}, 'rouge-2': {'f': 0.2857142807142858, 'p': 0.2857142857142857, 'r': 0.2857142857142857}, 'rouge-l': {'f': 0.4120879120877251, 'p': 0.5, 'r': 0.375}}]
#
# Text :  israel s cabinet on sunday discussed the most detailed plan ever offered to compensate settlers for leaving their homes in parts of the west bank ahead of a future peace deal with the palestinians <EOS>
#  Actual Summary :  israel mulls plan to compensate west bank settlers
#  System Summary :  inquiry for peace jirga in west bank peace jirga to israel to
#  [{'rouge-1': {'f': 0.4705882303114187, 'p': 0.4444444444444444, 'r': 0.5}, 'rouge-2': {'f': 0.11764705397923896, 'p': 0.1, 'r': 0.14285714285714285}, 'rouge-l': {'f': 0.23368251410092805, 'p': 0.2222222222222222, 'r': 0.25}}]
#
# Text :  israel expressed outrage on sunday after a mob of jewish settlers rampaged through a palestinian village in the west bank to avenge the stabbing of a nine year old boy in a nearby settlement <EOS>
#  Actual Summary :  israel outraged after settler rampage in west bank
#  System Summary :  obama urges israel to send gaza settlement in west bank west bank
#  [{'rouge-1': {'f': 0.4444444395061729, 'p': 0.4, 'r': 0.5}, 'rouge-2': {'f': 0.23529411280276827, 'p': 0.2, 'r': 0.2857142857142857}, 'rouge-l': {'f': 0.43386243386177037, 'p': 0.4, 'r': 0.5}}]
#
# Text :  israeli prime minister ehud olmert on sunday vowed to stop west bank `` pogroms a day after jewish settlers rampaged through a palestinian village shooting and wounding four people <EOS>
#  Actual Summary :  israel pm condemns settler pogroms after west bank clashes
#  System Summary :  reject west bank west bank west bank west bank west bank after
#  [{'rouge-1': {'f': 0.4615384572781066, 'p': 0.75, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.16666666222222234, 'p': 0.25, 'r': 0.125}, 'rouge-l': {'f': 0.2446406052964396, 'p': 0.5, 'r': 0.2222222222222222}}]
